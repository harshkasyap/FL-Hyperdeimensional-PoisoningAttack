# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import agg, data, fl, hdc, helper, log, nn, plot, poison, resnet, sim, wandb
from cfgs.fedargs import *

# %%
project = 'fl-poison'
name = 'fedavg-cnn-mnist-lfa-dp'

label_flip_attack["is"] = True
set_lfa_labels({4: 6})

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

#fedargs.agg_rule = agg.Rule.T_Mean
fedargs.tb = SummaryWriter('../out/runs/' + project + '/' + name, comment="fl")
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-poison/runs/it881692" target="_blank">fedavg-cnn-mnist-lfa-dp</a></strong> to <a href="https://wandb.ai/kasyah/fl-poison" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Device settings
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
# Prepare clients
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset, only_to_tensor = True)

# %% [markdown]
# <h2>FLTrust</h2>

# %%
if FLTrust["is"]:
    train_data, FLTrust["data"] = data.random_split(train_data, FLTrust["ratio"])
    FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
    
    if FLTrust["proxy"]["is"]:
        FLTrust["data"], FLTrust["proxy"]["data"] = data.random_split(FLTrust["data"], FLTrust["proxy"]["ratio"])
        FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
        FLTrust["proxy"]["loader"] = torch.utils.data.DataLoader(FLTrust["proxy"]["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Prepare a backdoored loader for test</h2>

# %%
if backdoor_attack["is"]:
    train_data, backdoor_attack["data"] = data.random_split(train_data, backdoor_attack["ratio"])
    backdoor_attack["data"] = poison.insert_trojan(backdoor_attack["data"],
                                                   backdoor_attack["target_label"],
                                                   backdoor_attack["trojan_func"], 1)
    backdoor_attack["loader"] = torch.utils.data.DataLoader(backdoor_attack["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Load client's data</h2>

# %%
clients_data = data.split_data(train_data, clients)

# %% [markdown]
# <h2>HDC DP Attack</h2>

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def hdc_train(hdc_data, device, hdc_args):
    hdc_data_loader = torch.utils.data.DataLoader(hdc_data, batch_size=len(hdc_data), shuffle=True)
    hdc_model = hdc.HDC(hdc_args["one_d_len"], hdc_args["hdc_proj_len"], len(hdc_args["labels"]), device)
    train_acc = hdc_model.train(hdc_data_loader, device)
    return hdc_model

if hdc_dp_attack["is"]:
    hdc_tasks = [hdc_train(clients_data[clients[client]], device,
                            hdc_dp_attack["args"]) for client in mal_clients]
    try:
        hdc_models = fedargs.loop.run_until_complete(asyncio.gather(*hdc_tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling hdc_dps...")
        hdc_tasks.cancel()
        fedargs.loop.run_forever()
        hdc_tasks.exception()

    hdc_clients_data = {client: (clients_data[clients[client]], hdc_models[index]) 
                        for index, client in enumerate(mal_clients)}

    mal_clients_data = hdc_dp_attack["func"](hdc_clients_data,
                                             hdc_dp_attack["args"],
                                             label_flip_attack["labels"],
                                             hdc_dp_attack["percent"])

    for client, mal_data in enumerate(mal_clients_data):
        clients_data[clients[client]] = mal_data

# %% [markdown]
# <h2>Label Flip Attack</h2>

# %%
if label_flip_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = label_flip_attack["func"](clients_data[clients[client]],
                                                                  label_flip_attack["labels"],
                                                                  label_flip_attack["percent"])

# %% [markdown]
# <h2>Backdoor Attack</h2>

# %%
if backdoor_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = poison.insert_trojan(clients_data[clients[client]],
                                                             backdoor_attack["target_label"],
                                                             backdoor_attack["trojan_func"], 0.5)

# %%
client_train_loaders, _ = data.load_client_data(clients_data, fedargs.client_batch_size, None, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, model, train_loader, fedargs, device):
    # Train
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    log.jsondebug(loss, "Epoch {} of {} : Federated Training loss, Client {}".format(epoch, fedargs.epochs, client))
    log.modeldebug(model_update, "Epoch {} of {} : Client {} Update".format(epoch, fedargs.epochs, client))
    
    return model_update

# %%
import time
start_time = time.time()
    
# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Global Model Update
    if epoch > 0:
        # For Tmean and FLTrust, not impacts others as of now
        avgargs = {"beta": len(mal_clients), 
                   "base_model_update": global_model_update if FLTrust["is"] else None,
                   "base_norm": True}
        
        # Average
        global_model = fl.federated_avg(client_model_updates, global_model, fedargs.agg_rule, **avgargs)
        log.modeldebug(global_model, "Epoch {}: Server Update".format(epoch))
        
        # Test, Plot and Log
        global_test_output = fedargs.eval_func(global_model, test_loader, device, label_flip_attack["labels"])
        fedargs.tb.add_scalar("Gloabl Accuracy/", global_test_output["accuracy"], epoch)
        fedargs.tb.add_scalar("Global Test Loss/", global_test_output["test_loss"], epoch)
        wb.log({"epoch": epoch, "time": time.time(), "acc": global_test_output["accuracy"], "loss": global_test_output["test_loss"]})
        log.jsoninfo(global_test_output, "Global Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))
        
        # Evaluate LFA
        if "attack" in global_test_output:
            if "attack_success_rate" in global_test_output["attack"]:
                fedargs.tb.add_scalar("Attack Success Rate/", global_test_output["attack"]["attack_success_rate"], epoch)
                wb.log({"attack_success_rate": global_test_output["attack"]["attack_success_rate"]})
            if "misclassification_rate" in global_test_output["attack"]:
                fedargs.tb.add_scalar("Misclassification Rate/", global_test_output["attack"]["misclassification_rate"], epoch)
                wb.log({"misclassification_rate": global_test_output["attack"]["misclassification_rate"]})

        # Evaluate Backdoor
        if backdoor_attack["is"]:
            backdoor_test_output = fl.backdoor_test(global_model, backdoor_attack["loader"], device, backdoor_attack["target_label"])
            fedargs.tb.add_scalar("Backdoor Success Rate/", backdoor_test_output["accuracy"], epoch)
            wb.log({"backdoor_success_rate": backdoor_test_output["accuracy"]})
            log.jsoninfo(backdoor_test_output, "Backdoor Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))

        # Update client models
        for client in clients:
            client_details[client]['model'] = copy.deepcopy(global_model)

    # Clients
    tasks = [process(client, epoch, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()

    for client, update in zip(clients, updates):
        client_details[client]['model_update'] = update
    client_model_updates = {client: details["model_update"] for client, details in client_details.items()}
    
    # Fang attack
    if fang_attack["is"]:
        client_model_updates = fang_attack["func"](client_model_updates, len(mal_clients), fang_attack["kn"])
        
    # LIE attack
    if lie_attack["is"]:
        client_model_updates = lie_attack["func"](client_model_updates, len(mal_clients), lie_attack["kn"])
   
    # SOTA attack
    if sota_attack["is"]:
        client_model_updates = sota_attack["func"](client_model_updates, len(mal_clients), 
                                                   sota_attack["kn"], sota_attack["dev_type"])
    
    # FLtrust or FLTC based aggregation rules or attacks
    if FLTrust["is"]:
        global_model_update, _, _ = fedargs.train_func(global_model, FLTrust["loader"],
                                                       fedargs.learning_rate,
                                                       fedargs.weight_decay,
                                                       fedargs.local_rounds, device)

        # For Attacks related to FLTrust
        base_model_update = global_model_update
        if FLTrust["proxy"]["is"]:
            base_model_update, _, _ = fedargs.train_func(global_model, FLTrust["proxy"]["loader"],
                                                         fedargs.learning_rate,
                                                         fedargs.weight_decay,
                                                         fedargs.local_rounds, device)
        
        # Layer replacement attack
        if layer_replacement_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = layer_replacement_attack["func"](base_model_update,
                                                                                                   client_details[clients[client]]['model_update'],
                                                                                                   layer_replacement_attack["layers"])

        # For cosine attack, Malicious Clients
        if cosine_attack["is"]:
            p_models, params_changed = cosine_attack["func"](base_model_update, cosine_attack["args"], epoch,
                                                             client_model_updates, len(mal_clients), cosine_attack["kn"])
            
            for client, p_model in enumerate(p_models):
                client_details[clients[client]]['model_update'] = p_model 

            #plot params changed for only one client
            fedargs.tb.add_scalar("Params Changed for Cosine Attack/", params_changed, epoch)

        # For sybil attack, Malicious Clients
        if sybil_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = base_model_update
                
        # again pair, as changed during attack
        client_model_updates = {client: details["model_update"] for client, details in client_details.items()}

print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-12-29 16:35:27,078 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
#   2%|▏         | 1/51 [00:32<27:24, 32.89s/it]2021-12-29 16:35:59,694 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:36:03,855 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 1 of 51 {
#     "accuracy": 38.39,
#     "attack": {
#         "attack_success_count": 4,
#         "attack_success_rate": 0.40733197556008144,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 3839,
#     "test_loss": 2.214659410095215
# } [MainProcess : MainThread (INFO)]
#   4%|▍         | 2/51 [01:09<28:24, 34.79s/it]2021-12-29 16:36:35,812 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:36:39,156 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 2 of 51 {
#     "accuracy": 64.36,
#     "attack": {
#         "attack_success_count": 38,
#         "attack_success_rate": 3.8696537678207736,
#         "instances": 982,
#         "misclassification_rate": 93.07535641547861,
#         "misclassifications": 914
#     },
#     "correct": 6436,
#     "test_loss": 2.012332596206665
# } [MainProcess : MainThread (INFO)]
#   6%|▌         | 3/51 [01:45<28:16, 35.35s/it]2021-12-29 16:37:11,835 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:37:14,842 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 3 of 51 {
#     "accuracy": 70.30999999999999,
#     "attack": {
#         "attack_success_count": 92,
#         "attack_success_rate": 9.368635437881874,
#         "instances": 982,
#         "misclassification_rate": 73.11608961303462,
#         "misclassifications": 718
#     },
#     "correct": 7031,
#     "test_loss": 1.7429632886886597
# } [MainProcess : MainThread (INFO)]
#   8%|▊         | 4/51 [02:20<27:50, 35.55s/it]2021-12-29 16:37:47,690 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:37:50,148 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 4 of 51 {
#     "accuracy": 74.41,
#     "attack": {
#         "attack_success_count": 97,
#         "attack_success_rate": 9.877800407331975,
#         "instances": 982,
#         "misclassification_rate": 53.360488798370675,
#         "misclassifications": 524
#     },
#     "correct": 7441,
#     "test_loss": 1.4612138248443602
# } [MainProcess : MainThread (INFO)]
#  10%|▉         | 5/51 [02:55<26:53, 35.09s/it]2021-12-29 16:38:21,948 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:38:24,219 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 5 of 51 {
#     "accuracy": 77.49000000000001,
#     "attack": {
#         "attack_success_count": 79,
#         "attack_success_rate": 8.04480651731161,
#         "instances": 982,
#         "misclassification_rate": 44.5010183299389,
#         "misclassifications": 437
#     },
#     "correct": 7749,
#     "test_loss": 1.205479280281067
# } [MainProcess : MainThread (INFO)]
#  12%|█▏        | 6/51 [03:29<26:07, 34.83s/it]2021-12-29 16:38:56,295 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:38:58,743 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 6 of 51 {
#     "accuracy": 79.54,
#     "attack": {
#         "attack_success_count": 73,
#         "attack_success_rate": 7.433808553971486,
#         "instances": 982,
#         "misclassification_rate": 38.79837067209776,
#         "misclassifications": 381
#     },
#     "correct": 7954,
#     "test_loss": 1.0007790051460266
# } [MainProcess : MainThread (INFO)]
#  14%|█▎        | 7/51 [04:04<25:28, 34.74s/it]2021-12-29 16:39:30,848 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 7 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:39:33,178 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 7 of 51 {
#     "accuracy": 81.41000000000001,
#     "attack": {
#         "attack_success_count": 67,
#         "attack_success_rate": 6.822810590631365,
#         "instances": 982,
#         "misclassification_rate": 32.79022403258656,
#         "misclassifications": 322
#     },
#     "correct": 8141,
#     "test_loss": 0.8464306975364685
# } [MainProcess : MainThread (INFO)]
#  16%|█▌        | 8/51 [04:38<24:47, 34.60s/it]2021-12-29 16:40:05,153 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 8 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:40:07,462 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 8 of 51 {
#     "accuracy": 82.87,
#     "attack": {
#         "attack_success_count": 62,
#         "attack_success_rate": 6.313645621181263,
#         "instances": 982,
#         "misclassification_rate": 30.24439918533605,
#         "misclassifications": 297
#     },
#     "correct": 8287,
#     "test_loss": 0.7322192806243897
# } [MainProcess : MainThread (INFO)]
#  18%|█▊        | 9/51 [05:12<24:09, 34.51s/it]2021-12-29 16:40:39,443 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 9 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:40:41,724 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 9 of 51 {
#     "accuracy": 84.03,
#     "attack": {
#         "attack_success_count": 58,
#         "attack_success_rate": 5.906313645621181,
#         "instances": 982,
#         "misclassification_rate": 27.698574338085542,
#         "misclassifications": 272
#     },
#     "correct": 8403,
#     "test_loss": 0.6509391721725464
# } [MainProcess : MainThread (INFO)]
#  20%|█▉        | 10/51 [05:46<23:23, 34.23s/it]2021-12-29 16:41:13,048 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 10 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:41:15,541 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 10 of 51 {
#     "accuracy": 85.14,
#     "attack": {
#         "attack_success_count": 54,
#         "attack_success_rate": 5.4989816700611,
#         "instances": 982,
#         "misclassification_rate": 24.643584521384927,
#         "misclassifications": 242
#     },
#     "correct": 8514,
#     "test_loss": 0.5887477835655213
# } [MainProcess : MainThread (INFO)]
#  22%|██▏       | 11/51 [06:21<23:05, 34.65s/it]2021-12-29 16:41:48,656 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 11 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:41:50,983 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 11 of 51 {
#     "accuracy": 85.72999999999999,
#     "attack": {
#         "attack_success_count": 52,
#         "attack_success_rate": 5.295315682281059,
#         "instances": 982,
#         "misclassification_rate": 23.828920570264767,
#         "misclassifications": 234
#     },
#     "correct": 8573,
#     "test_loss": 0.5440273380279541
# } [MainProcess : MainThread (INFO)]
#  24%|██▎       | 12/51 [06:56<22:34, 34.72s/it]2021-12-29 16:42:23,540 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 12 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:42:25,867 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 12 of 51 {
#     "accuracy": 86.33999999999999,
#     "attack": {
#         "attack_success_count": 49,
#         "attack_success_rate": 4.989816700610998,
#         "instances": 982,
#         "misclassification_rate": 21.89409368635438,
#         "misclassifications": 215
#     },
#     "correct": 8634,
#     "test_loss": 0.5110646360397338
# } [MainProcess : MainThread (INFO)]
#  25%|██▌       | 13/51 [07:31<22:03, 34.84s/it]2021-12-29 16:42:58,646 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 13 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:43:00,957 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 13 of 51 {
#     "accuracy": 86.92,
#     "attack": {
#         "attack_success_count": 45,
#         "attack_success_rate": 4.582484725050916,
#         "instances": 982,
#         "misclassification_rate": 21.384928716904277,
#         "misclassifications": 210
#     },
#     "correct": 8692,
#     "test_loss": 0.4810499322414398
# } [MainProcess : MainThread (INFO)]
#  27%|██▋       | 14/51 [08:06<21:25, 34.73s/it]2021-12-29 16:43:33,126 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 14 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:43:35,424 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 14 of 51 {
#     "accuracy": 87.59,
#     "attack": {
#         "attack_success_count": 41,
#         "attack_success_rate": 4.1751527494908345,
#         "instances": 982,
#         "misclassification_rate": 18.43177189409369,
#         "misclassifications": 181
#     },
#     "correct": 8759,
#     "test_loss": 0.4565196897029877
# } [MainProcess : MainThread (INFO)]
#  29%|██▉       | 15/51 [08:41<20:52, 34.80s/it]2021-12-29 16:44:08,103 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 15 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:44:10,514 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 15 of 51 {
#     "accuracy": 87.91,
#     "attack": {
#         "attack_success_count": 40,
#         "attack_success_rate": 4.0733197556008145,
#         "instances": 982,
#         "misclassification_rate": 16.90427698574338,
#         "misclassifications": 166
#     },
#     "correct": 8791,
#     "test_loss": 0.4389779360294342
# } [MainProcess : MainThread (INFO)]
#  31%|███▏      | 16/51 [09:15<20:15, 34.74s/it]2021-12-29 16:44:42,699 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 16 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:44:45,034 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 16 of 51 {
#     "accuracy": 88.2,
#     "attack": {
#         "attack_success_count": 37,
#         "attack_success_rate": 3.7678207739307537,
#         "instances": 982,
#         "misclassification_rate": 16.08961303462322,
#         "misclassifications": 158
#     },
#     "correct": 8820,
#     "test_loss": 0.42248878283500674
# } [MainProcess : MainThread (INFO)]
#  33%|███▎      | 17/51 [09:50<19:36, 34.62s/it]2021-12-29 16:45:17,031 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 17 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:45:19,399 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 17 of 51 {
#     "accuracy": 88.67,
#     "attack": {
#         "attack_success_count": 34,
#         "attack_success_rate": 3.462321792260693,
#         "instances": 982,
#         "misclassification_rate": 14.969450101832994,
#         "misclassifications": 147
#     },
#     "correct": 8867,
#     "test_loss": 0.4085504738807678
# } [MainProcess : MainThread (INFO)]
#  35%|███▌      | 18/51 [10:25<19:05, 34.70s/it]2021-12-29 16:45:51,924 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 18 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:45:54,256 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 18 of 51 {
#     "accuracy": 88.9,
#     "attack": {
#         "attack_success_count": 34,
#         "attack_success_rate": 3.462321792260693,
#         "instances": 982,
#         "misclassification_rate": 15.173116089613034,
#         "misclassifications": 149
#     },
#     "correct": 8890,
#     "test_loss": 0.396709872341156
# } [MainProcess : MainThread (INFO)]
#  37%|███▋      | 19/51 [11:00<18:35, 34.85s/it]2021-12-29 16:46:27,122 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 19 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:46:29,330 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 19 of 51 {
#     "accuracy": 89.21,
#     "attack": {
#         "attack_success_count": 30,
#         "attack_success_rate": 3.054989816700611,
#         "instances": 982,
#         "misclassification_rate": 13.64562118126273,
#         "misclassifications": 134
#     },
#     "correct": 8921,
#     "test_loss": 0.3854994124412537
# } [MainProcess : MainThread (INFO)]
#  39%|███▉      | 20/51 [11:34<17:54, 34.65s/it]2021-12-29 16:47:01,295 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 20 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:47:03,814 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 20 of 51 {
#     "accuracy": 89.4,
#     "attack": {
#         "attack_success_count": 32,
#         "attack_success_rate": 3.2586558044806515,
#         "instances": 982,
#         "misclassification_rate": 14.15478615071283,
#         "misclassifications": 139
#     },
#     "correct": 8940,
#     "test_loss": 0.37769486989974976
# } [MainProcess : MainThread (INFO)]
#  41%|████      | 21/51 [12:09<17:21, 34.72s/it]2021-12-29 16:47:36,181 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 21 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:47:38,515 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 21 of 51 {
#     "accuracy": 89.48,
#     "attack": {
#         "attack_success_count": 32,
#         "attack_success_rate": 3.2586558044806515,
#         "instances": 982,
#         "misclassification_rate": 14.562118126272914,
#         "misclassifications": 143
#     },
#     "correct": 8948,
#     "test_loss": 0.3699530264854431
# } [MainProcess : MainThread (INFO)]
#  43%|████▎     | 22/51 [12:44<16:52, 34.93s/it]2021-12-29 16:48:11,594 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 22 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:48:13,796 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 22 of 51 {
#     "accuracy": 89.91,
#     "attack": {
#         "attack_success_count": 29,
#         "attack_success_rate": 2.9531568228105907,
#         "instances": 982,
#         "misclassification_rate": 12.627291242362526,
#         "misclassifications": 124
#     },
#     "correct": 8991,
#     "test_loss": 0.3610651218414307
# } [MainProcess : MainThread (INFO)]
#  45%|████▌     | 23/51 [13:19<16:17, 34.90s/it]2021-12-29 16:48:46,437 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 23 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:48:48,702 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 23 of 51 {
#     "accuracy": 90.03999999999999,
#     "attack": {
#         "attack_success_count": 29,
#         "attack_success_rate": 2.9531568228105907,
#         "instances": 982,
#         "misclassification_rate": 12.016293279022404,
#         "misclassifications": 118
#     },
#     "correct": 9004,
#     "test_loss": 0.35416398100852964
# } [MainProcess : MainThread (INFO)]
#  47%|████▋     | 24/51 [13:54<15:40, 34.85s/it]2021-12-29 16:49:21,162 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 24 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:49:23,594 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 24 of 51 {
#     "accuracy": 90.28,
#     "attack": {
#         "attack_success_count": 27,
#         "attack_success_rate": 2.74949083503055,
#         "instances": 982,
#         "misclassification_rate": 11.303462321792262,
#         "misclassifications": 111
#     },
#     "correct": 9028,
#     "test_loss": 0.3476108918428421
# } [MainProcess : MainThread (INFO)]
#  49%|████▉     | 25/51 [14:28<15:00, 34.65s/it]2021-12-29 16:49:55,349 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 25 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:49:58,035 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 25 of 51 {
#     "accuracy": 90.34,
#     "attack": {
#         "attack_success_count": 28,
#         "attack_success_rate": 2.8513238289205702,
#         "instances": 982,
#         "misclassification_rate": 11.812627291242363,
#         "misclassifications": 116
#     },
#     "correct": 9034,
#     "test_loss": 0.34195047874450685
# } [MainProcess : MainThread (INFO)]
#  51%|█████     | 26/51 [15:03<14:25, 34.61s/it]2021-12-29 16:50:29,865 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 26 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:50:32,090 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 26 of 51 {
#     "accuracy": 90.53999999999999,
#     "attack": {
#         "attack_success_count": 27,
#         "attack_success_rate": 2.74949083503055,
#         "instances": 982,
#         "misclassification_rate": 10.79429735234216,
#         "misclassifications": 106
#     },
#     "correct": 9054,
#     "test_loss": 0.33628696637153627
# } [MainProcess : MainThread (INFO)]
#  53%|█████▎    | 27/51 [15:38<13:56, 34.85s/it]2021-12-29 16:51:05,286 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 27 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:51:07,778 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 27 of 51 {
#     "accuracy": 90.67,
#     "attack": {
#         "attack_success_count": 26,
#         "attack_success_rate": 2.6476578411405294,
#         "instances": 982,
#         "misclassification_rate": 10.386965376782078,
#         "misclassifications": 102
#     },
#     "correct": 9067,
#     "test_loss": 0.33048249950408937
# } [MainProcess : MainThread (INFO)]
#  55%|█████▍    | 28/51 [16:12<13:18, 34.73s/it]2021-12-29 16:51:39,735 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 28 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:51:42,073 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 28 of 51 {
#     "accuracy": 90.75,
#     "attack": {
#         "attack_success_count": 26,
#         "attack_success_rate": 2.6476578411405294,
#         "instances": 982,
#         "misclassification_rate": 11.201629327902241,
#         "misclassifications": 110
#     },
#     "correct": 9075,
#     "test_loss": 0.325573828792572
# } [MainProcess : MainThread (INFO)]
#  57%|█████▋    | 29/51 [16:47<12:40, 34.59s/it]2021-12-29 16:52:13,997 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 29 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:52:16,646 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 29 of 51 {
#     "accuracy": 90.93,
#     "attack": {
#         "attack_success_count": 25,
#         "attack_success_rate": 2.5458248472505094,
#         "instances": 982,
#         "misclassification_rate": 10.692464358452138,
#         "misclassifications": 105
#     },
#     "correct": 9093,
#     "test_loss": 0.3210802617073059
# } [MainProcess : MainThread (INFO)]
#  59%|█████▉    | 30/51 [17:21<12:07, 34.65s/it]2021-12-29 16:52:48,784 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 30 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:52:51,056 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 30 of 51 {
#     "accuracy": 90.91,
#     "attack": {
#         "attack_success_count": 26,
#         "attack_success_rate": 2.6476578411405294,
#         "instances": 982,
#         "misclassification_rate": 10.590631364562118,
#         "misclassifications": 104
#     },
#     "correct": 9091,
#     "test_loss": 0.31773599429130556
# } [MainProcess : MainThread (INFO)]
#  61%|██████    | 31/51 [17:55<11:25, 34.29s/it]2021-12-29 16:53:22,237 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 31 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:53:24,682 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 31 of 51 {
#     "accuracy": 91.01,
#     "attack": {
#         "attack_success_count": 24,
#         "attack_success_rate": 2.4439918533604885,
#         "instances": 982,
#         "misclassification_rate": 9.979633401221996,
#         "misclassifications": 98
#     },
#     "correct": 9101,
#     "test_loss": 0.31300973522663117
# } [MainProcess : MainThread (INFO)]
#  63%|██████▎   | 32/51 [18:30<10:55, 34.49s/it]2021-12-29 16:53:57,187 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 32 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:53:59,735 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 32 of 51 {
#     "accuracy": 91.13,
#     "attack": {
#         "attack_success_count": 23,
#         "attack_success_rate": 2.3421588594704685,
#         "instances": 982,
#         "misclassification_rate": 10.081466395112017,
#         "misclassifications": 99
#     },
#     "correct": 9113,
#     "test_loss": 0.30941541967391967
# } [MainProcess : MainThread (INFO)]
#  65%|██████▍   | 33/51 [19:03<10:14, 34.15s/it]2021-12-29 16:54:30,548 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 33 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:54:32,742 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 33 of 51 {
#     "accuracy": 91.17,
#     "attack": {
#         "attack_success_count": 23,
#         "attack_success_rate": 2.3421588594704685,
#         "instances": 982,
#         "misclassification_rate": 10.081466395112017,
#         "misclassifications": 99
#     },
#     "correct": 9117,
#     "test_loss": 0.3059527124643326
# } [MainProcess : MainThread (INFO)]
#  67%|██████▋   | 34/51 [19:38<09:43, 34.31s/it]2021-12-29 16:55:05,238 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 34 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:55:07,516 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 34 of 51 {
#     "accuracy": 91.23,
#     "attack": {
#         "attack_success_count": 23,
#         "attack_success_rate": 2.3421588594704685,
#         "instances": 982,
#         "misclassification_rate": 9.674134419551935,
#         "misclassifications": 95
#     },
#     "correct": 9123,
#     "test_loss": 0.3029849828362465
# } [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [20:12<09:09, 34.32s/it]2021-12-29 16:55:39,573 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 35 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:55:41,827 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 35 of 51 {
#     "accuracy": 91.33,
#     "attack": {
#         "attack_success_count": 22,
#         "attack_success_rate": 2.240325865580448,
#         "instances": 982,
#         "misclassification_rate": 9.470468431771895,
#         "misclassifications": 93
#     },
#     "correct": 9133,
#     "test_loss": 0.2988804725885391
# } [MainProcess : MainThread (INFO)]
#  71%|███████   | 36/51 [20:46<08:31, 34.07s/it]2021-12-29 16:56:13,078 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 36 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:56:15,594 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 36 of 51 {
#     "accuracy": 91.34,
#     "attack": {
#         "attack_success_count": 22,
#         "attack_success_rate": 2.240325865580448,
#         "instances": 982,
#         "misclassification_rate": 9.674134419551935,
#         "misclassifications": 95
#     },
#     "correct": 9134,
#     "test_loss": 0.29601428565979004
# } [MainProcess : MainThread (INFO)]
#  73%|███████▎  | 37/51 [21:19<07:51, 33.69s/it]2021-12-29 16:56:45,874 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 37 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:56:48,252 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 37 of 51 {
#     "accuracy": 91.46,
#     "attack": {
#         "attack_success_count": 22,
#         "attack_success_rate": 2.240325865580448,
#         "instances": 982,
#         "misclassification_rate": 9.470468431771895,
#         "misclassifications": 93
#     },
#     "correct": 9146,
#     "test_loss": 0.2925329425573349
# } [MainProcess : MainThread (INFO)]
#  75%|███████▍  | 38/51 [21:52<07:16, 33.57s/it]2021-12-29 16:57:19,159 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 38 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:57:21,475 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 38 of 51 {
#     "accuracy": 91.55,
#     "attack": {
#         "attack_success_count": 21,
#         "attack_success_rate": 2.1384928716904277,
#         "instances": 982,
#         "misclassification_rate": 9.266802443991853,
#         "misclassifications": 91
#     },
#     "correct": 9155,
#     "test_loss": 0.28947126579284665
# } [MainProcess : MainThread (INFO)]
#  76%|███████▋  | 39/51 [22:26<06:44, 33.69s/it]2021-12-29 16:57:53,127 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 39 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:57:55,415 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 39 of 51 {
#     "accuracy": 91.58,
#     "attack": {
#         "attack_success_count": 20,
#         "attack_success_rate": 2.0366598778004072,
#         "instances": 982,
#         "misclassification_rate": 8.45213849287169,
#         "misclassifications": 83
#     },
#     "correct": 9158,
#     "test_loss": 0.28675752086639406
# } [MainProcess : MainThread (INFO)]
#  78%|███████▊  | 40/51 [23:00<06:12, 33.89s/it]2021-12-29 16:58:27,488 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 40 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:58:29,724 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 40 of 51 {
#     "accuracy": 91.67999999999999,
#     "attack": {
#         "attack_success_count": 20,
#         "attack_success_rate": 2.0366598778004072,
#         "instances": 982,
#         "misclassification_rate": 8.757637474541752,
#         "misclassifications": 86
#     },
#     "correct": 9168,
#     "test_loss": 0.28345685024261474
# } [MainProcess : MainThread (INFO)]
#  80%|████████  | 41/51 [23:35<05:40, 34.03s/it]2021-12-29 16:59:01,849 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 41 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:59:04,169 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 41 of 51 {
#     "accuracy": 91.71000000000001,
#     "attack": {
#         "attack_success_count": 20,
#         "attack_success_rate": 2.0366598778004072,
#         "instances": 982,
#         "misclassification_rate": 8.961303462321792,
#         "misclassifications": 88
#     },
#     "correct": 9171,
#     "test_loss": 0.2805726707935333
# } [MainProcess : MainThread (INFO)]
#  82%|████████▏ | 42/51 [24:10<05:08, 34.31s/it]2021-12-29 16:59:36,808 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 42 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 16:59:38,962 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 42 of 51 {
#     "accuracy": 91.71000000000001,
#     "attack": {
#         "attack_success_count": 20,
#         "attack_success_rate": 2.0366598778004072,
#         "instances": 982,
#         "misclassification_rate": 8.655804480651732,
#         "misclassifications": 85
#     },
#     "correct": 9171,
#     "test_loss": 0.2789957331776619
# } [MainProcess : MainThread (INFO)]
#  84%|████████▍ | 43/51 [24:44<04:33, 34.25s/it]2021-12-29 17:00:10,904 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 43 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:00:13,155 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 43 of 51 {
#     "accuracy": 91.75999999999999,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.757637474541752,
#         "misclassifications": 86
#     },
#     "correct": 9176,
#     "test_loss": 0.2759762436628342
# } [MainProcess : MainThread (INFO)]
#  86%|████████▋ | 44/51 [25:17<03:57, 33.88s/it]2021-12-29 17:00:43,915 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 44 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:00:46,146 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 44 of 51 {
#     "accuracy": 91.81,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.859470468431772,
#         "misclassifications": 87
#     },
#     "correct": 9181,
#     "test_loss": 0.273472163271904
# } [MainProcess : MainThread (INFO)]
#  88%|████████▊ | 45/51 [25:50<03:22, 33.82s/it]2021-12-29 17:01:17,614 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 45 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:01:19,786 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 45 of 51 {
#     "accuracy": 91.9,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.350305498981669,
#         "misclassifications": 82
#     },
#     "correct": 9190,
#     "test_loss": 0.2708117939472198
# } [MainProcess : MainThread (INFO)]
#  90%|█████████ | 46/51 [26:23<02:46, 33.36s/it]2021-12-29 17:01:49,902 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 46 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:01:52,043 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 46 of 51 {
#     "accuracy": 91.93,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.350305498981669,
#         "misclassifications": 82
#     },
#     "correct": 9193,
#     "test_loss": 0.26909336647987364
# } [MainProcess : MainThread (INFO)]
#  92%|█████████▏| 47/51 [26:56<02:14, 33.50s/it]2021-12-29 17:02:23,724 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 47 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:02:25,860 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 47 of 51 {
#     "accuracy": 91.97999999999999,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.757637474541752,
#         "misclassifications": 86
#     },
#     "correct": 9198,
#     "test_loss": 0.26687220851182936
# } [MainProcess : MainThread (INFO)]
#  94%|█████████▍| 48/51 [27:29<01:39, 33.29s/it]2021-12-29 17:02:56,528 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 48 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:02:58,711 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 48 of 51 {
#     "accuracy": 92.06,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.24847250509165,
#         "misclassifications": 81
#     },
#     "correct": 9206,
#     "test_loss": 0.2643667432308197
# } [MainProcess : MainThread (INFO)]
#  96%|█████████▌| 49/51 [28:03<01:06, 33.33s/it]2021-12-29 17:03:29,957 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 49 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:03:32,210 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 49 of 51 {
#     "accuracy": 92.14,
#     "attack": {
#         "attack_success_count": 19,
#         "attack_success_rate": 1.9348268839103868,
#         "instances": 982,
#         "misclassification_rate": 8.350305498981669,
#         "misclassifications": 82
#     },
#     "correct": 9214,
#     "test_loss": 0.2623706509590149
# } [MainProcess : MainThread (INFO)]
#  98%|█████████▊| 50/51 [28:36<00:33, 33.43s/it]2021-12-29 17:04:03,609 - <ipython-input-14-97ccfc536289>::<module>(l:6) : Federated Training Epoch 50 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 17:04:05,813 - <ipython-input-14-97ccfc536289>::<module>(l:24) : Global Test Outut after Epoch 50 of 51 {
#     "accuracy": 92.23,
#     "attack": {
#         "attack_success_count": 18,
#         "attack_success_rate": 1.8329938900203666,
#         "instances": 982,
#         "misclassification_rate": 8.146639511201629,
#         "misclassifications": 80
#     },
#     "correct": 9223,
#     "test_loss": 0.26011173542141913
# } [MainProcess : MainThread (INFO)]
# 100%|██████████| 51/51 [29:09<00:00, 34.31s/it]
# 1749.8692224025726

# %% [markdown]
# <h1> End </h1>
