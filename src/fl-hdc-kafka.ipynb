# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import agg, data, fl, hdc, log, nn, plot, poison, resnet, sim, wandb
from libs.distributed import *
from cfgs.fedargs import *

# %%
project = 'fl-hdc-kafka'
fedargs.epochs = 10
fedargs.topic = 'hdc'
fedargs.num_clients = 5
fedargs.one_d_len = 3072
fedargs.dataset = 'cifar10'
name = 'fedavg-cnn-cifar10-na'

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

fedargs.tb = SummaryWriter('../out/runs/' + project + '/' + name, comment="fl")
#plot = plot.init(name, project)
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-hdc-kafka/runs/3rg3qbnf" target="_blank">fedavg-cnn-cifar10-na</a></strong> to <a href="https://wandb.ai/kasyah/fl-hdc-kafka" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Distributed topology
dt = Distributed(clients, fedargs.broker_ip, fedargs.schema_ip, fedargs.wait_to_consume)

# %%
# Initialize Global and Client models
fedargs.model = hdc.HDC(fedargs.one_d_len, fedargs.hdc_proj_len, len(fedargs.labels), device)
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset, only_to_tensor = True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
clients_data = data.split_data(train_data, clients)

# %%
client_train_loaders, client_test_loaders = data.load_client_data(clients_data, batch_size=-1, 0.2, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=len(test_data), shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "test_loader": client_test_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, dt, model, train_loader, test_loader, fedargs, device):
    log.info("Epoch: {}, Processing Client {}".format(epoch, client))
    
    # Consume and Average, epoch passed is actually prev epoch, for which we want to consume updates
    client_model_updates = dt.consume_model(client, fedargs.topic, model, epoch)

    log.info("Epoch: {}, Client {} received {} model update(s) from {}".format(epoch, client, 
                                                                               len(client_model_updates), 
                                                                               list(client_model_updates.keys())))
    
    if len(client_model_updates) != 0:
        model.avg(list(client_model_updates.values()))

    # Train    
    train_acc = model.train(train_loader, device)

    # Publish
    epoch = epoch + 1
    dt.produce_model(client, fedargs.topic, model, epoch)

    log.info("Epoch {} : Federated Training accuracy {}, Client {}".format(epoch, train_acc, client))

    # Test, Plot and Log
    test_acc = model.test(test_loader, device)
    fedargs.tb.add_scalar("Accuracy/" + client, test_acc, epoch)
    #plot.alog(client, {epoch: {"time": time.time(), "acc": test_acc}})
    wb.log({client: {"epoch": epoch, "time": time.time(), "acc": test_acc}})
    log.info("Test accuracy {} after Epoch {} of {} for Client {}".format(test_acc, epoch, fedargs.epochs, client))

    return model

# %%
import time
start_time = time.time()

# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Clients  
    tasks = [process(client, epoch, dt, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     client_details[client]['test_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()
    
print(time.time() - start_time)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]2021-11-08 14:41:30,072 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 0 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:41:30,171 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:41:30,177 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:41:30,178 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:41:30,179 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:41:30,179 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 0, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:41:40,211 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 0, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:41:40,242 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 0, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:41:40,280 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 0, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:41:40,285 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 0, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:41:40,287 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 0, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:04,302 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:05,117 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:05,225 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:05,677 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 280 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:06,368 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 1 : Federated Training accuracy 30.337501525878906, Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:06,391 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:06,420 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 281 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:06,496 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 1 : Federated Training accuracy 30.000001907348633, Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:07,088 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:07,299 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:08,171 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 282 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:08,249 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 1 : Federated Training accuracy 29.975000381469727, Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:09,745 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:10,413 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:10,766 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 283 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:10,830 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 1 : Federated Training accuracy 29.787498474121094, Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:10,955 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:11,120 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:12,007 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 284 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:12,045 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 1 : Federated Training accuracy 29.037498474121094, Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:12,462 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.600000381469727 after Epoch 1 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:12,552 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.049999237060547 after Epoch 1 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:13,574 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.499998092651367 after Epoch 1 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:14,247 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.499998092651367 after Epoch 1 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:14,875 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.700000762939453 after Epoch 1 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
#  10%|█         | 1/10 [00:45<06:46, 45.18s/it]2021-11-08 14:42:14,973 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 1 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:42:15,008 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:15,040 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:15,101 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:15,102 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:15,103 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 1, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:25,099 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 1, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:25,172 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 1, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:25,234 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 1, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:25,242 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 1, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:25,245 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 1, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:45,883 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:46,089 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:46,874 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 285 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:46,935 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 2 : Federated Training accuracy 30.012500762939453, Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:48,573 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:48,793 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:49,574 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 286 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:49,597 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 2 : Federated Training accuracy 30.19999885559082, Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:56,132 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.249998092651367 after Epoch 2 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:42:56,387 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.950000762939453 after Epoch 2 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:42:56,893 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:57,401 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:57,776 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:57,868 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:58,437 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:58,464 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 287 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:58,492 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 2 : Federated Training accuracy 29.112499237060547, Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:42:58,627 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:58,644 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 288 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:58,662 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 2 : Federated Training accuracy 30.012500762939453, Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:42:59,444 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 289 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:42:59,464 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 2 : Federated Training accuracy 30.137500762939453, Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:00,059 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.350000381469727 after Epoch 2 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:00,628 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.100000381469727 after Epoch 2 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:01,370 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 30.25 after Epoch 2 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
#  20%|██        | 2/10 [01:31<06:07, 45.95s/it]2021-11-08 14:43:01,465 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 2 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:43:01,526 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:01,539 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:01,539 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:01,541 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:01,541 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 2, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:11,573 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 2, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:11,630 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 2, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:11,679 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 2, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:11,686 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 2, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:11,686 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 2, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:40,510 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:40,723 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:41,506 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 290 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:41,544 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 3 : Federated Training accuracy 30.274999618530273, Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:46,211 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.80000114440918 after Epoch 3 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:51,818 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:52,898 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:53,787 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 291 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:53,799 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:54,016 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 3 : Federated Training accuracy 29.6875, Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:54,085 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:54,246 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:54,733 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:54,769 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:54,796 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:55,026 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 292 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:55,049 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 3 : Federated Training accuracy 30.05000114440918, Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:55,223 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 293 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:55,242 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 3 : Federated Training accuracy 30.137500762939453, Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:55,578 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 294 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:55,598 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 3 : Federated Training accuracy 28.787500381469727, Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:56,423 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.750001907348633 after Epoch 3 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:43:57,741 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.94999885559082 after Epoch 3 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:58,583 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.750001907348633 after Epoch 3 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:58,822 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.149999618530273 after Epoch 3 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_0 (INFO)]
#  30%|███       | 3/10 [02:29<05:58, 51.21s/it]2021-11-08 14:43:58,920 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 3 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:43:58,971 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:43:59,027 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:43:59,029 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:43:59,030 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:43:59,030 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 3, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:09,039 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 3, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:09,100 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 3, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:44:09,118 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 3, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:09,149 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 3, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:09,180 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 3, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:37,041 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:37,780 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:37,781 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:37,889 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 295 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:37,918 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 4 : Federated Training accuracy 30.537500381469727, Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:38,023 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:38,911 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 296 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:38,932 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 4 : Federated Training accuracy 29.9375, Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:44,861 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.350000381469727 after Epoch 4 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:45,064 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.499998092651367 after Epoch 4 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:45,275 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:45,641 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:46,347 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 297 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:46,362 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 4 : Federated Training accuracy 30.30000114440918, Client bladecluster.iitp.org(2) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:47,418 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:47,968 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:48,421 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 298 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:48,471 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 4 : Federated Training accuracy 29.149999618530273, Client bladecluster.iitp.org(3) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:48,471 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:44:48,695 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:44:49,136 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.149999618530273 after Epoch 4 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:49,420 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 299 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:44:49,437 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 4 : Federated Training accuracy 30.087501525878906, Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:44:50,229 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.19999885559082 after Epoch 4 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:51,009 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 30.100000381469727 after Epoch 4 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
#  40%|████      | 4/10 [03:21<05:09, 51.59s/it]2021-11-08 14:44:51,086 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 4 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:44:51,167 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:44:51,167 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:44:51,174 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:44:51,174 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:44:51,174 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 4, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:01,212 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 4, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:01,300 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 4, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:01,305 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 4, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:01,306 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 4, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:01,307 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 4, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(5)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:30,558 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:30,778 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:31,581 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 300 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:31,641 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 5 : Federated Training accuracy 30.16250228881836, Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:33,056 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:33,359 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:34,054 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 301 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:34,074 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 5 : Federated Training accuracy 29.92500114440918, Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:36,231 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.600000381469727 after Epoch 5 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:39,773 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.249998092651367 after Epoch 5 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:39,785 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:40,726 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:40,762 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:40,954 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:41,904 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 303 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:41,909 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 302 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:42,007 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:42,035 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 5 : Federated Training accuracy 30.25, Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:42,037 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 5 : Federated Training accuracy 30.612499237060547, Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:42,163 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:43,026 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 304 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:43,054 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 5 : Federated Training accuracy 28.787500381469727, Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:43,816 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.399999618530273 after Epoch 5 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:43,987 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.94999885559082 after Epoch 5 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:44,833 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.950000762939453 after Epoch 5 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
#  50%|█████     | 5/10 [04:15<04:21, 52.39s/it]2021-11-08 14:45:44,903 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 5 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:45:44,945 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:44,957 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:44,994 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:45,012 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:45,012 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 5, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:45:55,089 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 5, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:45:55,101 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 5, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:45:55,174 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 5, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:45:55,175 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 5, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:45:55,183 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 5, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:24,522 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:25,407 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:25,733 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 305 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:25,824 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 6 : Federated Training accuracy 29.737499237060547, Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:28,013 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:28,664 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:29,425 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:29,942 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:30,005 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 306 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:30,194 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 6 : Federated Training accuracy 29.024999618530273, Client bladecluster.iitp.org(3) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:30,598 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 307 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:30,666 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 6 : Federated Training accuracy 30.1875, Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:32,409 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:32,537 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:46:32,749 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:32,792 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:46:33,498 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 308 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:33,600 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 6 : Federated Training accuracy 30.212501525878906, Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:33,615 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.30000114440918 after Epoch 6 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:33,615 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 309 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:46:33,716 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 6 : Federated Training accuracy 30.5625, Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:46:35,559 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.899999618530273 after Epoch 6 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:35,924 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.100000381469727 after Epoch 6 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:36,897 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.0 after Epoch 6 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:37,019 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.249998092651367 after Epoch 6 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
#  60%|██████    | 6/10 [05:07<03:29, 52.34s/it]2021-11-08 14:46:37,145 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 6 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:46:37,226 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:37,244 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:46:37,245 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:37,245 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:37,248 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 6, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:47,426 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 6, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:46:47,426 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 6, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:46:47,427 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 6, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:46:47,427 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 6, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:46:47,430 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 6, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(4)', 'bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:47:11,829 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:47:12,369 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:47:12,845 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 310 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:47:12,974 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 7 : Federated Training accuracy 30.337501525878906, Client bladecluster.iitp.org(1) [MainProcess : asyncio_3 (INFO)]
# ...
# 2021-11-08 14:48:14,236 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 8 : Federated Training accuracy 29.887500762939453, Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:48:15,882 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.499998092651367 after Epoch 8 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:48:16,893 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.60000228881836 after Epoch 8 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:17,043 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.0 after Epoch 8 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:48:17,627 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.80000114440918 after Epoch 8 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_2 (INFO)]
#  80%|████████  | 8/10 [06:47<01:42, 51.46s/it]2021-11-08 14:48:17,684 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 8 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:48:17,754 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 8, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:48:17,762 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 8, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:48:17,767 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 8, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:48:17,767 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 8, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:48:17,767 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 8, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:27,901 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 8, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:48:27,907 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 8, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:48:27,926 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 8, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:27,927 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 8, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:48:27,932 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 8, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:48:54,955 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:55,120 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:55,959 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 320 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:55,986 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 9 : Federated Training accuracy 29.049999237060547, Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:48:59,527 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:00,056 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:00,532 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 321 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:00,617 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 9 : Federated Training accuracy 30.237499237060547, Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:01,262 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.499998092651367 after Epoch 9 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:06,217 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:06,401 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.399999618530273 after Epoch 9 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:06,665 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:06,674 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:07,033 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:07,057 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:07,077 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:07,103 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 322 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:07,116 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 9 : Federated Training accuracy 30.1875, Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:07,421 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 323 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:07,437 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 9 : Federated Training accuracy 30.30000114440918, Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:07,672 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 324 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:07,690 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 9 : Federated Training accuracy 29.92500114440918, Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:08,091 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 28.700000762939453 after Epoch 9 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:09,545 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.399999618530273 after Epoch 9 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:09,779 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 29.249998092651367 after Epoch 9 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_3 (INFO)]
#  90%|█████████ | 9/10 [07:40<00:51, 51.68s/it]2021-11-08 14:49:09,855 - <ipython-input-10-cc316da67b86>::<module>(l:6) : Federated Training Epoch 9 of 10 [MainProcess : MainThread (INFO)]
# 2021-11-08 14:49:09,931 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 9, Processing Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:09,965 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 9, Processing Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:09,967 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 9, Processing Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:09,968 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 9, Processing Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:09,973 - <ipython-input-9-d25a439eb414>::process(l:9) : Epoch: 9, Processing Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:20,033 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 9, Client bladecluster.iitp.org(1) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:20,108 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 9, Client bladecluster.iitp.org(3) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:20,111 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 9, Client bladecluster.iitp.org(4) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:20,118 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 9, Client bladecluster.iitp.org(2) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:20,131 - <ipython-input-9-d25a439eb414>::process(l:14) : Epoch: 9, Client bladecluster.iitp.org(5) received 5 model update(s) from ['bladecluster.iitp.org(3)', 'bladecluster.iitp.org(1)', 'bladecluster.iitp.org(5)', 'bladecluster.iitp.org(2)', 'bladecluster.iitp.org(4)'] [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:47,035 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:47,207 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:48,044 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(2)' successfully produced to hdc [0] at offset 325 [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:48,066 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 10 : Federated Training accuracy 9.774999618530273, Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:51,603 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:51,795 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:52,622 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(1)' successfully produced to hdc [0] at offset 326 [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:52,656 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 10 : Federated Training accuracy 10.0, Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:53,619 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 9.600000381469727 after Epoch 10 of 10 for Client bladecluster.iitp.org(2) [MainProcess : asyncio_0 (INFO)]
# 2021-11-08 14:49:58,283 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 9.600000381469727 after Epoch 10 of 10 for Client bladecluster.iitp.org(1) [MainProcess : asyncio_4 (INFO)]
# 2021-11-08 14:49:58,661 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:59,506 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:49:59,584 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:59,730 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:56) : Producing user records to topic hdc. ^C to exit. [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:49:59,768 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(3)' successfully produced to hdc [0] at offset 327 [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:49:59,818 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 10 : Federated Training accuracy 9.800000190734863, Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:50:00,122 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:50:00,167 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::produce(l:66) : Flushing records... [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:50:00,364 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(5)' successfully produced to hdc [0] at offset 328 [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:50:00,381 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 10 : Federated Training accuracy 9.987500190734863, Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:50:00,728 - /home/harsh_1921cs01/hub/AgroFed/fl/libs/protobuf_producer.py::delivery_report(l:50) : User record b'bladecluster.iitp.org(4)' successfully produced to hdc [0] at offset 329 [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:50:00,747 - <ipython-input-9-d25a439eb414>::process(l:28) : Epoch 10 : Federated Training accuracy 10.387499809265137, Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 2021-11-08 14:50:01,771 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 10.699999809265137 after Epoch 10 of 10 for Client bladecluster.iitp.org(3) [MainProcess : asyncio_2 (INFO)]
# 2021-11-08 14:50:02,996 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 10.40000057220459 after Epoch 10 of 10 for Client bladecluster.iitp.org(5) [MainProcess : asyncio_3 (INFO)]
# 2021-11-08 14:50:03,177 - <ipython-input-9-d25a439eb414>::process(l:35) : Test accuracy 11.050000190734863 after Epoch 10 of 10 for Client bladecluster.iitp.org(4) [MainProcess : asyncio_1 (INFO)]
# 100%|██████████| 10/10 [08:33<00:00, 51.35s/it]
# 513.5412526130676

# %% [markdown]
# <h1> End </h1>
