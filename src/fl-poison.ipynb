# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../")))
from libs import agg, data, fl, hdc, helper, log, nn, plot, poison, resnet, sim, wandb
from cfgs.fedargs import *

# %%
project = 'fl-poison'
name = 'fedavg-cnn-mnist-hdc-dp'

hdc_dp_attack["is"] = True
set_lfa_labels({4: 6})

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

#fedargs.agg_rule = agg.Rule.T_Mean
fedargs.tb = SummaryWriter('../out/runs/' + project + '/' + name, comment="fl")
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-poison/runs/qg5gjo9b" target="_blank">fedavg-cnn-mnist-hdc-dp</a></strong> to <a href="https://wandb.ai/kasyah/fl-poison" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Device settings
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
# Prepare clients
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset, only_to_tensor = True)

# %% [markdown]
# <h2>FLTrust</h2>

# %%
if FLTrust["is"]:
    train_data, FLTrust["data"] = data.random_split(train_data, FLTrust["ratio"])
    FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
    
    if FLTrust["proxy"]["is"]:
        FLTrust["data"], FLTrust["proxy"]["data"] = data.random_split(FLTrust["data"], FLTrust["proxy"]["ratio"])
        FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
        FLTrust["proxy"]["loader"] = torch.utils.data.DataLoader(FLTrust["proxy"]["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Prepare a backdoored loader for test</h2>

# %%
if backdoor_attack["is"]:
    train_data, backdoor_attack["data"] = data.random_split(train_data, backdoor_attack["ratio"])
    backdoor_attack["data"] = poison.insert_trojan(backdoor_attack["data"],
                                                   backdoor_attack["target_label"],
                                                   backdoor_attack["trojan_func"], 1)
    backdoor_attack["loader"] = torch.utils.data.DataLoader(backdoor_attack["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Load client's data</h2>

# %%
clients_data = data.split_data(train_data, clients)

# %% [markdown]
# <h2>HDC DP Attack</h2>

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def hdc_train(hdc_data, device, hdc_args):
    hdc_data_loader = torch.utils.data.DataLoader(hdc_data, batch_size=len(hdc_data), shuffle=True)
    hdc_model = hdc.HDC(hdc_args["one_d_len"], hdc_args["hdc_proj_len"], len(hdc_args["labels"]), device)
    train_acc = hdc_model.train(hdc_data_loader, device)
    return hdc_model

if hdc_dp_attack["is"]:
    hdc_tasks = [hdc_train(clients_data[clients[client]], device,
                            hdc_dp_attack["args"]) for client in mal_clients]
    try:
        hdc_models = fedargs.loop.run_until_complete(asyncio.gather(*hdc_tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling hdc_dps...")
        hdc_tasks.cancel()
        fedargs.loop.run_forever()
        hdc_tasks.exception()

    hdc_clients_data = {client: (clients_data[clients[client]], hdc_models[index])
                        for index, client in enumerate(mal_clients)}

    mal_clients_data = hdc_dp_attack["func"](hdc_clients_data,
                                             hdc_dp_attack["args"],
                                             label_flip_attack["labels"],
                                             hdc_dp_attack["percent"])

    for client, mal_data in enumerate(mal_clients_data):
        clients_data[clients[client]] = mal_data

# %% [markdown]
# <h2>Label Flip Attack</h2>

# %%
if label_flip_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = label_flip_attack["func"](clients_data[clients[client]],
                                                                  label_flip_attack["labels"],
                                                                  label_flip_attack["percent"])

# %% [markdown]
# <h2>Backdoor Attack</h2>

# %%
if backdoor_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = poison.insert_trojan(clients_data[clients[client]],
                                                             backdoor_attack["target_label"],
                                                             backdoor_attack["trojan_func"], 0.5)

# %%
client_train_loaders, _ = data.load_client_data(clients_data, fedargs.client_batch_size, None, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, model, train_loader, fedargs, device):
    # Train
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    log.jsondebug(loss, "Epoch {} of {} : Federated Training loss, Client {}".format(epoch, fedargs.epochs, client))
    log.modeldebug(model_update, "Epoch {} of {} : Client {} Update".format(epoch, fedargs.epochs, client))
    
    return model_update

# %%
import time
start_time = time.time()
    
# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Global Model Update
    if epoch > 0:
        # For Tmean and FLTrust, not impacts others as of now
        avgargs = {"beta": len(mal_clients), 
                   "base_model_update": global_model_update if FLTrust["is"] else None,
                   "base_norm": True}
        
        # Average
        global_model = fl.federated_avg(client_model_updates, global_model, fedargs.agg_rule, **avgargs)
        log.modeldebug(global_model, "Epoch {}: Server Update".format(epoch))
        
        # Test, Plot and Log
        global_test_output = fedargs.eval_func(global_model, test_loader, device, label_flip_attack["labels"])
        fedargs.tb.add_scalar("Gloabl Accuracy/", global_test_output["accuracy"], epoch)
        fedargs.tb.add_scalar("Global Test Loss/", global_test_output["test_loss"], epoch)
        wb.log({"epoch": epoch, "time": time.time(), "acc": global_test_output["accuracy"], "loss": global_test_output["test_loss"]})
        log.jsoninfo(global_test_output, "Global Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))
        
        # Evaluate LFA
        if "attack" in global_test_output:
            if "attack_success_rate" in global_test_output["attack"]:
                wb.log({"attack_success_rate": global_test_output["attack"]["attack_success_rate"]})
                fedargs.tb.add_scalar("Attack Success Rate/", global_test_output["attack"]["attack_success_rate"], epoch)
            if "misclassification_rate" in global_test_output["attack"]:
                wb.log({"misclassification_rate": global_test_output["attack"]["misclassification_rate"]})
                fedargs.tb.add_scalar("Misclassification Rate/", global_test_output["attack"]["misclassification_rate"], epoch)

        # Evaluate Backdoor
        if backdoor_attack["is"]:
            backdoor_test_output = fl.backdoor_test(global_model, backdoor_attack["loader"], device, backdoor_attack["target_label"])
            fedargs.tb.add_scalar("Backdoor Success Rate/", backdoor_test_output["accuracy"], epoch)
            wb.log({"backdoor_success_rate": backdoor_test_output["accuracy"]})
            log.jsoninfo(backdoor_test_output, "Backdoor Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))

        # Update client models
        for client in clients:
            client_details[client]['model'] = copy.deepcopy(global_model)

    # Clients
    tasks = [process(client, epoch, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()

    for client, update in zip(clients, updates):
        client_details[client]['model_update'] = update
    client_model_updates = {client: details["model_update"] for client, details in client_details.items()}
    
    # Fang attack
    if fang_attack["is"]:
        client_model_updates = fang_attack["func"](client_model_updates, len(mal_clients), fang_attack["kn"])
        
    # LIE attack
    if lie_attack["is"]:
        client_model_updates = lie_attack["func"](client_model_updates, len(mal_clients), lie_attack["kn"])
   
    # SOTA attack
    if sota_attack["is"]:
        client_model_updates = sota_attack["func"](client_model_updates, len(mal_clients), 
                                                   sota_attack["kn"], sota_attack["dev_type"])
    
    # FLtrust or FLTC based aggregation rules or attacks
    if FLTrust["is"]:
        global_model_update, _, _ = fedargs.train_func(global_model, FLTrust["loader"],
                                                       fedargs.learning_rate,
                                                       fedargs.weight_decay,
                                                       fedargs.local_rounds, device)

        # For Attacks related to FLTrust
        base_model_update = global_model_update
        if FLTrust["proxy"]["is"]:
            base_model_update, _, _ = fedargs.train_func(global_model, FLTrust["proxy"]["loader"],
                                                         fedargs.learning_rate,
                                                         fedargs.weight_decay,
                                                         fedargs.local_rounds, device)
        
        # Layer replacement attack
        if layer_replacement_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = layer_replacement_attack["func"](base_model_update,
                                                                                                   client_details[clients[client]]['model_update'],
                                                                                                   layer_replacement_attack["layers"])

        # For cosine attack, Malicious Clients
        if cosine_attack["is"]:
            p_models, params_changed = cosine_attack["func"](base_model_update, cosine_attack["args"], epoch,
                                                             client_model_updates, len(mal_clients), cosine_attack["kn"])
            
            for client, p_model in enumerate(p_models):
                client_details[clients[client]]['model_update'] = p_model 

            #plot params changed for only one client
            fedargs.tb.add_scalar("Params Changed for Cosine Attack/", params_changed, epoch)

        # For sybil attack, Malicious Clients
        if sybil_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = base_model_update
                
        # again pair, as changed during attack
        client_model_updates = {client: details["model_update"] for client, details in client_details.items()}

print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-12-29 19:21:58,994 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
#   2%|▏         | 1/51 [00:51<42:55, 51.51s/it]2021-12-29 19:22:50,248 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:22:53,273 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 1 of 51 {
#     "accuracy": 9.58,
#     "attack": {
#         "attack_success_count": 982,
#         "attack_success_rate": 100.0,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 958,
#     "test_loss": 2.289267569351196
# } [MainProcess : MainThread (INFO)]
#   4%|▍         | 2/51 [01:42<41:35, 50.94s/it]2021-12-29 19:23:40,774 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:23:43,231 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 2 of 51 {
#     "accuracy": 9.58,
#     "attack": {
#         "attack_success_count": 982,
#         "attack_success_rate": 100.0,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 958,
#     "test_loss": 2.143662828063965
# } [MainProcess : MainThread (INFO)]
#   6%|▌         | 3/51 [02:32<40:44, 50.92s/it]2021-12-29 19:24:31,674 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:24:34,076 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 3 of 51 {
#     "accuracy": 13.41,
#     "attack": {
#         "attack_success_count": 982,
#         "attack_success_rate": 100.0,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 1341,
#     "test_loss": 1.9501509220123292
# } [MainProcess : MainThread (INFO)]
#   8%|▊         | 4/51 [03:24<40:08, 51.23s/it]2021-12-29 19:25:23,398 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:25:25,873 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 4 of 51 {
#     "accuracy": 23.49,
#     "attack": {
#         "attack_success_count": 982,
#         "attack_success_rate": 100.0,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 2349,
#     "test_loss": 1.7381517026901245
# } [MainProcess : MainThread (INFO)]
#  10%|▉         | 5/51 [04:15<39:06, 51.01s/it]2021-12-29 19:26:14,012 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:26:16,665 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 5 of 51 {
#     "accuracy": 32.18,
#     "attack": {
#         "attack_success_count": 981,
#         "attack_success_rate": 99.89816700610999,
#         "instances": 982,
#         "misclassification_rate": 100.0,
#         "misclassifications": 982
#     },
#     "correct": 3218,
#     "test_loss": 1.53474764919281
# } [MainProcess : MainThread (INFO)]
#  12%|█▏        | 6/51 [05:07<38:34, 51.43s/it]2021-12-29 19:27:06,254 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:27:08,557 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 6 of 51 {
#     "accuracy": 40.77,
#     "attack": {
#         "attack_success_count": 944,
#         "attack_success_rate": 96.13034623217924,
#         "instances": 982,
#         "misclassification_rate": 96.74134419551935,
#         "misclassifications": 950
#     },
#     "correct": 4077,
#     "test_loss": 1.3388491342544555
# } [MainProcess : MainThread (INFO)]
#  14%|█▎        | 7/51 [05:59<37:55, 51.72s/it]2021-12-29 19:27:58,562 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 7 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:28:01,021 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 7 of 51 {
#     "accuracy": 50.63999999999999,
#     "attack": {
#         "attack_success_count": 774,
#         "attack_success_rate": 78.81873727087576,
#         "instances": 982,
#         "misclassification_rate": 81.05906313645622,
#         "misclassifications": 796
#     },
#     "correct": 5064,
#     "test_loss": 1.1909669010162354
# } [MainProcess : MainThread (INFO)]
#  16%|█▌        | 8/51 [06:50<36:55, 51.53s/it]2021-12-29 19:28:49,699 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 8 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:28:52,036 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 8 of 51 {
#     "accuracy": 58.550000000000004,
#     "attack": {
#         "attack_success_count": 606,
#         "attack_success_rate": 61.710794297352344,
#         "instances": 982,
#         "misclassification_rate": 66.90427698574338,
#         "misclassifications": 657
#     },
#     "correct": 5855,
#     "test_loss": 1.0761596813201904
# } [MainProcess : MainThread (INFO)]
#  18%|█▊        | 9/51 [07:42<36:10, 51.67s/it]2021-12-29 19:29:41,668 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 9 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:29:43,920 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 9 of 51 {
#     "accuracy": 66.17,
#     "attack": {
#         "attack_success_count": 463,
#         "attack_success_rate": 47.14867617107943,
#         "instances": 982,
#         "misclassification_rate": 55.60081466395111,
#         "misclassifications": 546
#     },
#     "correct": 6617,
#     "test_loss": 0.953427767753601
# } [MainProcess : MainThread (INFO)]
#  20%|█▉        | 10/51 [08:36<35:42, 52.26s/it]2021-12-29 19:30:35,242 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 10 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:30:37,610 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 10 of 51 {
#     "accuracy": 70.86,
#     "attack": {
#         "attack_success_count": 372,
#         "attack_success_rate": 37.88187372708758,
#         "instances": 982,
#         "misclassification_rate": 47.657841140529534,
#         "misclassifications": 468
#     },
#     "correct": 7086,
#     "test_loss": 0.8630140583992004
# } [MainProcess : MainThread (INFO)]
#  22%|██▏       | 11/51 [09:29<34:55, 52.39s/it]2021-12-29 19:31:27,940 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 11 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:31:30,198 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 11 of 51 {
#     "accuracy": 73.81,
#     "attack": {
#         "attack_success_count": 304,
#         "attack_success_rate": 30.95723014256619,
#         "instances": 982,
#         "misclassification_rate": 42.057026476578415,
#         "misclassifications": 413
#     },
#     "correct": 7381,
#     "test_loss": 0.7963517196655273
# } [MainProcess : MainThread (INFO)]
#  24%|██▎       | 12/51 [10:20<33:47, 51.99s/it]2021-12-29 19:32:19,027 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 12 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:32:21,330 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 12 of 51 {
#     "accuracy": 76.06,
#     "attack": {
#         "attack_success_count": 275,
#         "attack_success_rate": 28.0040733197556,
#         "instances": 982,
#         "misclassification_rate": 38.39103869653768,
#         "misclassifications": 377
#     },
#     "correct": 7606,
#     "test_loss": 0.7396889295578003
# } [MainProcess : MainThread (INFO)]
#  25%|██▌       | 13/51 [11:13<33:11, 52.42s/it]2021-12-29 19:33:12,412 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 13 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:33:14,668 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 13 of 51 {
#     "accuracy": 77.9,
#     "attack": {
#         "attack_success_count": 238,
#         "attack_success_rate": 24.236252545824847,
#         "instances": 982,
#         "misclassification_rate": 33.91038696537678,
#         "misclassifications": 333
#     },
#     "correct": 7790,
#     "test_loss": 0.686333117389679
# } [MainProcess : MainThread (INFO)]
#  27%|██▋       | 14/51 [12:07<32:34, 52.81s/it]2021-12-29 19:34:06,131 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 14 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:34:08,407 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 14 of 51 {
#     "accuracy": 79.5,
#     "attack": {
#         "attack_success_count": 222,
#         "attack_success_rate": 22.606924643584524,
#         "instances": 982,
#         "misclassification_rate": 32.17922606924644,
#         "misclassifications": 316
#     },
#     "correct": 7950,
#     "test_loss": 0.6447981786251068
# } [MainProcess : MainThread (INFO)]
#  29%|██▉       | 15/51 [12:58<31:26, 52.41s/it]2021-12-29 19:34:57,610 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 15 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:35:00,114 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 15 of 51 {
#     "accuracy": 80.78,
#     "attack": {
#         "attack_success_count": 195,
#         "attack_success_rate": 19.85743380855397,
#         "instances": 982,
#         "misclassification_rate": 29.022403258655803,
#         "misclassifications": 285
#     },
#     "correct": 8078,
#     "test_loss": 0.6092352731704712
# } [MainProcess : MainThread (INFO)]
#  31%|███▏      | 16/51 [13:51<30:33, 52.38s/it]2021-12-29 19:35:49,932 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 16 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:35:52,444 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 16 of 51 {
#     "accuracy": 82.03,
#     "attack": {
#         "attack_success_count": 186,
#         "attack_success_rate": 18.94093686354379,
#         "instances": 982,
#         "misclassification_rate": 27.90224032586558,
#         "misclassifications": 274
#     },
#     "correct": 8203,
#     "test_loss": 0.5820149798393249
# } [MainProcess : MainThread (INFO)]
#  33%|███▎      | 17/51 [14:43<29:40, 52.35s/it]2021-12-29 19:36:42,221 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 17 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:36:44,487 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 17 of 51 {
#     "accuracy": 82.91,
#     "attack": {
#         "attack_success_count": 161,
#         "attack_success_rate": 16.39511201629328,
#         "instances": 982,
#         "misclassification_rate": 25.254582484725052,
#         "misclassifications": 248
#     },
#     "correct": 8291,
#     "test_loss": 0.5544676448822021
# } [MainProcess : MainThread (INFO)]
#  35%|███▌      | 18/51 [15:34<28:34, 51.97s/it]2021-12-29 19:37:33,294 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 18 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:37:35,983 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 18 of 51 {
#     "accuracy": 83.88,
#     "attack": {
#         "attack_success_count": 149,
#         "attack_success_rate": 15.173116089613034,
#         "instances": 982,
#         "misclassification_rate": 23.625254582484725,
#         "misclassifications": 232
#     },
#     "correct": 8388,
#     "test_loss": 0.5326379806518554
# } [MainProcess : MainThread (INFO)]
#  37%|███▋      | 19/51 [16:26<27:46, 52.06s/it]2021-12-29 19:38:25,582 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 19 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:38:27,939 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 19 of 51 {
#     "accuracy": 84.55,
#     "attack": {
#         "attack_success_count": 143,
#         "attack_success_rate": 14.562118126272914,
#         "instances": 982,
#         "misclassification_rate": 22.912423625254583,
#         "misclassifications": 225
#     },
#     "correct": 8455,
#     "test_loss": 0.5172695739746094
# } [MainProcess : MainThread (INFO)]
#  39%|███▉      | 20/51 [17:20<27:06, 52.46s/it]2021-12-29 19:39:18,971 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 20 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:39:21,284 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 20 of 51 {
#     "accuracy": 85.08,
#     "attack": {
#         "attack_success_count": 136,
#         "attack_success_rate": 13.849287169042771,
#         "instances": 982,
#         "misclassification_rate": 22.19959266802444,
#         "misclassifications": 218
#     },
#     "correct": 8508,
#     "test_loss": 0.5002948090553284
# } [MainProcess : MainThread (INFO)]
#  41%|████      | 21/51 [18:11<26:00, 52.02s/it]2021-12-29 19:40:09,968 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 21 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:40:12,285 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 21 of 51 {
#     "accuracy": 85.58,
#     "attack": {
#         "attack_success_count": 127,
#         "attack_success_rate": 12.932790224032587,
#         "instances": 982,
#         "misclassification_rate": 21.181262729124235,
#         "misclassifications": 208
#     },
#     "correct": 8558,
#     "test_loss": 0.4845711923599243
# } [MainProcess : MainThread (INFO)]
#  43%|████▎     | 22/51 [19:03<25:14, 52.21s/it]2021-12-29 19:41:02,613 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 22 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:41:04,956 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 22 of 51 {
#     "accuracy": 85.98,
#     "attack": {
#         "attack_success_count": 121,
#         "attack_success_rate": 12.321792260692463,
#         "instances": 982,
#         "misclassification_rate": 20.366598778004075,
#         "misclassifications": 200
#     },
#     "correct": 8598,
#     "test_loss": 0.471700227355957
# } [MainProcess : MainThread (INFO)]
#  45%|████▌     | 23/51 [19:56<24:26, 52.39s/it]2021-12-29 19:41:55,418 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 23 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:41:57,876 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 23 of 51 {
#     "accuracy": 86.52,
#     "attack": {
#         "attack_success_count": 116,
#         "attack_success_rate": 11.812627291242363,
#         "instances": 982,
#         "misclassification_rate": 20.061099796334013,
#         "misclassifications": 197
#     },
#     "correct": 8652,
#     "test_loss": 0.45570682539939883
# } [MainProcess : MainThread (INFO)]
#  47%|████▋     | 24/51 [20:50<23:48, 52.91s/it]2021-12-29 19:42:49,544 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 24 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:42:52,055 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 24 of 51 {
#     "accuracy": 86.76,
#     "attack": {
#         "attack_success_count": 109,
#         "attack_success_rate": 11.09979633401222,
#         "instances": 982,
#         "misclassification_rate": 18.839103869653766,
#         "misclassifications": 185
#     },
#     "correct": 8676,
#     "test_loss": 0.44586698160171506
# } [MainProcess : MainThread (INFO)]
#  49%|████▉     | 25/51 [21:43<22:53, 52.81s/it]2021-12-29 19:43:42,116 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 25 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:43:44,481 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 25 of 51 {
#     "accuracy": 86.86,
#     "attack": {
#         "attack_success_count": 111,
#         "attack_success_rate": 11.303462321792262,
#         "instances": 982,
#         "misclassification_rate": 18.839103869653766,
#         "misclassifications": 185
#     },
#     "correct": 8686,
#     "test_loss": 0.4409998374462128
# } [MainProcess : MainThread (INFO)]
#  51%|█████     | 26/51 [22:35<21:55, 52.64s/it]2021-12-29 19:44:34,358 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 26 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:44:36,659 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 26 of 51 {
#     "accuracy": 87.22999999999999,
#     "attack": {
#         "attack_success_count": 105,
#         "attack_success_rate": 10.692464358452138,
#         "instances": 982,
#         "misclassification_rate": 17.617107942973522,
#         "misclassifications": 173
#     },
#     "correct": 8723,
#     "test_loss": 0.43083771924972536
# } [MainProcess : MainThread (INFO)]
#  53%|█████▎    | 27/51 [23:26<20:52, 52.19s/it]2021-12-29 19:45:25,492 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 27 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:45:27,836 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 27 of 51 {
#     "accuracy": 87.6,
#     "attack": {
#         "attack_success_count": 97,
#         "attack_success_rate": 9.877800407331975,
#         "instances": 982,
#         "misclassification_rate": 16.39511201629328,
#         "misclassifications": 161
#     },
#     "correct": 8760,
#     "test_loss": 0.4206688952445984
# } [MainProcess : MainThread (INFO)]
#  55%|█████▍    | 28/51 [24:18<19:53, 51.91s/it]2021-12-29 19:46:16,746 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 28 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:46:19,162 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 28 of 51 {
#     "accuracy": 87.82,
#     "attack": {
#         "attack_success_count": 97,
#         "attack_success_rate": 9.877800407331975,
#         "instances": 982,
#         "misclassification_rate": 16.700610997963338,
#         "misclassifications": 164
#     },
#     "correct": 8782,
#     "test_loss": 0.41546583814620974
# } [MainProcess : MainThread (INFO)]
#  57%|█████▋    | 29/51 [25:09<19:01, 51.87s/it]2021-12-29 19:47:08,544 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 29 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:47:10,827 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 29 of 51 {
#     "accuracy": 88.1,
#     "attack": {
#         "attack_success_count": 91,
#         "attack_success_rate": 9.266802443991853,
#         "instances": 982,
#         "misclassification_rate": 15.682281059063136,
#         "misclassifications": 154
#     },
#     "correct": 8810,
#     "test_loss": 0.4057015733718872
# } [MainProcess : MainThread (INFO)]
#  59%|█████▉    | 30/51 [26:01<18:08, 51.83s/it]2021-12-29 19:48:00,269 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 30 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:48:02,822 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 30 of 51 {
#     "accuracy": 88.24,
#     "attack": {
#         "attack_success_count": 90,
#         "attack_success_rate": 9.164969450101832,
#         "instances": 982,
#         "misclassification_rate": 15.580448065173117,
#         "misclassifications": 153
#     },
#     "correct": 8824,
#     "test_loss": 0.4001398681640625
# } [MainProcess : MainThread (INFO)]
#  61%|██████    | 31/51 [26:54<17:24, 52.21s/it]2021-12-29 19:48:53,353 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 31 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:48:55,588 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 31 of 51 {
#     "accuracy": 88.64,
#     "attack": {
#         "attack_success_count": 87,
#         "attack_success_rate": 8.859470468431772,
#         "instances": 982,
#         "misclassification_rate": 14.765784114052954,
#         "misclassifications": 145
#     },
#     "correct": 8864,
#     "test_loss": 0.3923197214126587
# } [MainProcess : MainThread (INFO)]
#  63%|██████▎   | 32/51 [27:46<16:32, 52.21s/it]2021-12-29 19:49:45,585 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 32 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:49:47,930 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 32 of 51 {
#     "accuracy": 88.75,
#     "attack": {
#         "attack_success_count": 87,
#         "attack_success_rate": 8.859470468431772,
#         "instances": 982,
#         "misclassification_rate": 15.071283095723015,
#         "misclassifications": 148
#     },
#     "correct": 8875,
#     "test_loss": 0.3868231122970581
# } [MainProcess : MainThread (INFO)]
#  65%|██████▍   | 33/51 [28:39<15:43, 52.39s/it]2021-12-29 19:50:38,391 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 33 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:50:40,557 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 33 of 51 {
#     "accuracy": 88.84,
#     "attack": {
#         "attack_success_count": 87,
#         "attack_success_rate": 8.859470468431772,
#         "instances": 982,
#         "misclassification_rate": 14.969450101832994,
#         "misclassifications": 147
#     },
#     "correct": 8884,
#     "test_loss": 0.38415132459402085
# } [MainProcess : MainThread (INFO)]
#  67%|██████▋   | 34/51 [29:30<14:45, 52.06s/it]2021-12-29 19:51:29,675 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 34 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:51:32,077 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 34 of 51 {
#     "accuracy": 89.14,
#     "attack": {
#         "attack_success_count": 83,
#         "attack_success_rate": 8.45213849287169,
#         "instances": 982,
#         "misclassification_rate": 14.15478615071283,
#         "misclassifications": 139
#     },
#     "correct": 8914,
#     "test_loss": 0.37457995777130126
# } [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [30:24<13:58, 52.44s/it]2021-12-29 19:52:22,990 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 35 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:52:25,466 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 35 of 51 {
#     "accuracy": 89.12,
#     "attack": {
#         "attack_success_count": 87,
#         "attack_success_rate": 8.859470468431772,
#         "instances": 982,
#         "misclassification_rate": 14.663951120162933,
#         "misclassifications": 144
#     },
#     "correct": 8912,
#     "test_loss": 0.37370492148399354
# } [MainProcess : MainThread (INFO)]
#  71%|███████   | 36/51 [31:17<13:09, 52.65s/it]2021-12-29 19:53:16,127 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 36 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:53:18,445 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 36 of 51 {
#     "accuracy": 89.33,
#     "attack": {
#         "attack_success_count": 82,
#         "attack_success_rate": 8.350305498981669,
#         "instances": 982,
#         "misclassification_rate": 13.849287169042771,
#         "misclassifications": 136
#     },
#     "correct": 8933,
#     "test_loss": 0.3697631603717804
# } [MainProcess : MainThread (INFO)]
#  73%|███████▎  | 37/51 [32:09<12:15, 52.54s/it]2021-12-29 19:54:08,415 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 37 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:54:10,670 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 37 of 51 {
#     "accuracy": 89.49000000000001,
#     "attack": {
#         "attack_success_count": 80,
#         "attack_success_rate": 8.146639511201629,
#         "instances": 982,
#         "misclassification_rate": 13.54378818737271,
#         "misclassifications": 133
#     },
#     "correct": 8949,
#     "test_loss": 0.36451753039360046
# } [MainProcess : MainThread (INFO)]
#  75%|███████▍  | 38/51 [33:04<11:33, 53.32s/it]2021-12-29 19:55:03,556 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 38 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:55:05,672 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 38 of 51 {
#     "accuracy": 89.58,
#     "attack": {
#         "attack_success_count": 79,
#         "attack_success_rate": 8.04480651731161,
#         "instances": 982,
#         "misclassification_rate": 13.340122199592669,
#         "misclassifications": 131
#     },
#     "correct": 8958,
#     "test_loss": 0.3589638763487339
# } [MainProcess : MainThread (INFO)]
#  76%|███████▋  | 39/51 [33:56<10:33, 52.75s/it]2021-12-29 19:55:54,984 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 39 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:55:57,325 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 39 of 51 {
#     "accuracy": 89.84,
#     "attack": {
#         "attack_success_count": 76,
#         "attack_success_rate": 7.739307535641547,
#         "instances": 982,
#         "misclassification_rate": 13.136456211812627,
#         "misclassifications": 129
#     },
#     "correct": 8984,
#     "test_loss": 0.3531025999069214
# } [MainProcess : MainThread (INFO)]
#  78%|███████▊  | 40/51 [34:49<09:42, 52.98s/it]2021-12-29 19:56:48,494 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 40 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:56:50,758 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 40 of 51 {
#     "accuracy": 89.88000000000001,
#     "attack": {
#         "attack_success_count": 78,
#         "attack_success_rate": 7.942973523421588,
#         "instances": 982,
#         "misclassification_rate": 13.238289205702646,
#         "misclassifications": 130
#     },
#     "correct": 8988,
#     "test_loss": 0.3513706485748291
# } [MainProcess : MainThread (INFO)]
#  80%|████████  | 41/51 [35:43<08:50, 53.10s/it]2021-12-29 19:57:41,868 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 41 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:57:44,180 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 41 of 51 {
#     "accuracy": 89.92,
#     "attack": {
#         "attack_success_count": 75,
#         "attack_success_rate": 7.637474541751528,
#         "instances": 982,
#         "misclassification_rate": 12.627291242362526,
#         "misclassifications": 124
#     },
#     "correct": 8992,
#     "test_loss": 0.3498153191804886
# } [MainProcess : MainThread (INFO)]
#  82%|████████▏ | 42/51 [36:34<07:53, 52.65s/it]2021-12-29 19:58:33,476 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 42 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:58:35,704 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 42 of 51 {
#     "accuracy": 90.06,
#     "attack": {
#         "attack_success_count": 74,
#         "attack_success_rate": 7.535641547861507,
#         "instances": 982,
#         "misclassification_rate": 12.423625254582484,
#         "misclassifications": 122
#     },
#     "correct": 9006,
#     "test_loss": 0.3455326284408569
# } [MainProcess : MainThread (INFO)]
#  84%|████████▍ | 43/51 [37:26<06:59, 52.45s/it]2021-12-29 19:59:25,461 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 43 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 19:59:27,718 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 43 of 51 {
#     "accuracy": 90.27,
#     "attack": {
#         "attack_success_count": 68,
#         "attack_success_rate": 6.924643584521386,
#         "instances": 982,
#         "misclassification_rate": 12.016293279022404,
#         "misclassifications": 118
#     },
#     "correct": 9027,
#     "test_loss": 0.33659685101509096
# } [MainProcess : MainThread (INFO)]
#  86%|████████▋ | 44/51 [38:19<06:08, 52.57s/it]2021-12-29 20:00:18,323 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 44 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:00:20,965 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 44 of 51 {
#     "accuracy": 90.27,
#     "attack": {
#         "attack_success_count": 72,
#         "attack_success_rate": 7.3319755600814664,
#         "instances": 982,
#         "misclassification_rate": 12.016293279022404,
#         "misclassifications": 118
#     },
#     "correct": 9027,
#     "test_loss": 0.3397075569152832
# } [MainProcess : MainThread (INFO)]
#  88%|████████▊ | 45/51 [39:13<05:17, 53.00s/it]2021-12-29 20:01:12,325 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 45 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:01:14,780 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 45 of 51 {
#     "accuracy": 90.42,
#     "attack": {
#         "attack_success_count": 71,
#         "attack_success_rate": 7.230142566191446,
#         "instances": 982,
#         "misclassification_rate": 11.812627291242363,
#         "misclassifications": 116
#     },
#     "correct": 9042,
#     "test_loss": 0.33348084268569944
# } [MainProcess : MainThread (INFO)]
#  90%|█████████ | 46/51 [40:06<04:24, 52.84s/it]2021-12-29 20:02:04,792 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 46 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:02:07,166 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 46 of 51 {
#     "accuracy": 90.42999999999999,
#     "attack": {
#         "attack_success_count": 69,
#         "attack_success_rate": 7.026476578411406,
#         "instances": 982,
#         "misclassification_rate": 12.016293279022404,
#         "misclassifications": 118
#     },
#     "correct": 9043,
#     "test_loss": 0.3307067967414856
# } [MainProcess : MainThread (INFO)]
#  92%|█████████▏| 47/51 [40:59<03:32, 53.14s/it]2021-12-29 20:02:58,630 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 47 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:03:00,942 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 47 of 51 {
#     "accuracy": 90.62,
#     "attack": {
#         "attack_success_count": 70,
#         "attack_success_rate": 7.128309572301425,
#         "instances": 982,
#         "misclassification_rate": 11.608961303462321,
#         "misclassifications": 114
#     },
#     "correct": 9062,
#     "test_loss": 0.3261315775871277
# } [MainProcess : MainThread (INFO)]
#  94%|█████████▍| 48/51 [41:55<02:41, 53.84s/it]2021-12-29 20:03:54,112 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 48 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:03:56,325 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 48 of 51 {
#     "accuracy": 90.71000000000001,
#     "attack": {
#         "attack_success_count": 68,
#         "attack_success_rate": 6.924643584521386,
#         "instances": 982,
#         "misclassification_rate": 11.405295315682281,
#         "misclassifications": 112
#     },
#     "correct": 9071,
#     "test_loss": 0.32262315273284914
# } [MainProcess : MainThread (INFO)]
#  96%|█████████▌| 49/51 [42:50<01:48, 54.14s/it]2021-12-29 20:04:48,949 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 49 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:04:51,376 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 49 of 51 {
#     "accuracy": 90.83,
#     "attack": {
#         "attack_success_count": 69,
#         "attack_success_rate": 7.026476578411406,
#         "instances": 982,
#         "misclassification_rate": 11.507128309572302,
#         "misclassifications": 113
#     },
#     "correct": 9083,
#     "test_loss": 0.3196304963469505
# } [MainProcess : MainThread (INFO)]
#  98%|█████████▊| 50/51 [43:45<00:54, 54.60s/it]2021-12-29 20:05:44,622 - <ipython-input-14-ff08476993c1>::<module>(l:6) : Federated Training Epoch 50 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-29 20:05:46,904 - <ipython-input-14-ff08476993c1>::<module>(l:24) : Global Test Outut after Epoch 50 of 51 {
#     "accuracy": 90.99000000000001,
#     "attack": {
#         "attack_success_count": 64,
#         "attack_success_rate": 6.517311608961303,
#         "instances": 982,
#         "misclassification_rate": 10.79429735234216,
#         "misclassifications": 106
#     },
#     "correct": 9099,
#     "test_loss": 0.3169107693195343
# } [MainProcess : MainThread (INFO)]
# 100%|██████████| 51/51 [44:39<00:00, 52.55s/it]
# 2679.839318037033

# %% [markdown]
# <h1> End </h1>
