# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../../")))
from libs import agg, data, fl, hdc, helper, log, ltbl, nn, plot, poison, resnet, sim, wandb
from cfgs.fedargs import *

# %%
project = 'fl-hdc-dp'
name = 'fedavg-mnist-na'

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

#fedargs.agg_rule = agg.Rule.T_Mean
fedargs.tb = SummaryWriter('../../out/runs/' + project + '/' + name, comment="fl")
data_dict = {'epochs':[], 'acc': [], 'test_loss': []}
ltbl = ltbl.init(data_dict, name, project)
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-hdc-dp/runs/1z9rhb1k" target="_blank">fedavg-mnist-na</a></strong> to <a href="https://wandb.ai/kasyah/fl-hdc-dp" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Device settings
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
# Prepare clients
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset, only_to_tensor = True)

# %% [markdown]
# <h2>FLTrust</h2>

# %%
if FLTrust["is"]:
    train_data, FLTrust["data"] = data.random_split(train_data, FLTrust["ratio"])
    FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
    
    if FLTrust["proxy"]["is"]:
        FLTrust["data"], FLTrust["proxy"]["data"] = data.random_split(FLTrust["data"], FLTrust["proxy"]["ratio"])
        FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
        FLTrust["proxy"]["loader"] = torch.utils.data.DataLoader(FLTrust["proxy"]["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Prepare a backdoored loader for test</h2>

# %%
if backdoor_attack["is"]:
    train_data, backdoor_attack["data"] = data.random_split(train_data, backdoor_attack["ratio"])
    backdoor_attack["data"] = poison.insert_trojan(backdoor_attack["data"],
                                                   backdoor_attack["target_label"],
                                                   backdoor_attack["trojan_func"], 1)
    backdoor_attack["loader"] = torch.utils.data.DataLoader(backdoor_attack["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Load client's data</h2>

# %%
clients_data = data.split_data(train_data, clients)

# %% [markdown]
# <h2>HDC DP Attack</h2>

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def hdc_train(hdc_data, device, hdc_args):
    hdc_data_loader = torch.utils.data.DataLoader(hdc_data, batch_size=len(hdc_data), shuffle=True)
    hdc_model = hdc.HDC(hdc_args["one_d_len"], hdc_args["hdc_proj_len"], len(hdc_args["labels"]), device)
    train_acc = hdc_model.train(hdc_data_loader, device)
    return hdc_model

if hdc_dp_attack["is"]:
    hdc_tasks = [hdc_train(clients_data[clients[client]], device,
                            hdc_dp_attack["args"]) for client in mal_clients]
    try:
        hdc_models = fedargs.loop.run_until_complete(asyncio.gather(*hdc_tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling hdc_dps...")
        hdc_tasks.cancel()
        fedargs.loop.run_forever()
        hdc_tasks.exception()

    hdc_clients_data = {client: (clients_data[clients[client]], hdc_models[index])
                        for index, client in enumerate(mal_clients)}

    mal_clients_data = hdc_dp_attack["func"](hdc_clients_data,
                                             hdc_dp_attack["args"],
                                             label_flip_attack["labels"],
                                             hdc_dp_attack["percent"])

    for client, mal_data in enumerate(mal_clients_data):
        clients_data[clients[client]] = mal_data

# %% [markdown]
# <h2>Label Flip Attack</h2>

# %%
if label_flip_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = label_flip_attack["func"](clients_data[clients[client]],
                                                                  label_flip_attack["labels"],
                                                                  label_flip_attack["percent"])

# %% [markdown]
# <h2>Backdoor Attack</h2>

# %%
if backdoor_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = poison.insert_trojan(clients_data[clients[client]],
                                                             backdoor_attack["target_label"],
                                                             backdoor_attack["trojan_func"], 0.5)

# %%
client_train_loaders, _ = data.load_client_data(clients_data, fedargs.client_batch_size, None, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, model, train_loader, fedargs, device):
    # Train
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    log.jsondebug(loss, "Epoch {} of {} : Federated Training loss, Client {}".format(epoch, fedargs.epochs, client))
    log.modeldebug(model_update, "Epoch {} of {} : Client {} Update".format(epoch, fedargs.epochs, client))
    
    return model_update

# %%
import time
start_time = time.time()
    
# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Global Model Update
    if epoch > 0:
        # For Tmean and FLTrust, not impacts others as of now
        avgargs = {"beta": len(mal_clients), 
                   "base_model_update": global_model_update if FLTrust["is"] else None,
                   "base_norm": True}
        
        # Average
        global_model = fl.federated_avg(client_model_updates, global_model, fedargs.agg_rule, **avgargs)
        log.modeldebug(global_model, "Epoch {}: Server Update".format(epoch))
        
        # Test, Plot and Log
        global_test_output = fedargs.eval_func(global_model, test_loader, device, label_flip_attack["labels"])
        fedargs.tb.add_scalar("Gloabl Accuracy/", global_test_output["accuracy"], epoch)
        fedargs.tb.add_scalar("Global Test Loss/", global_test_output["test_loss"], epoch)
        wb.log({"epoch": epoch, "time": time.time(), "acc": global_test_output["accuracy"], "loss": global_test_output["test_loss"]})
        log.jsoninfo(global_test_output, "Global Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))
        
        # Evaluate LFA
        if "attack" in global_test_output:
            if "attack_success_rate" in global_test_output["attack"]:
                wb.log({"attack_success_rate": global_test_output["attack"]["attack_success_rate"]})
                fedargs.tb.add_scalar("Attack Success Rate/", global_test_output["attack"]["attack_success_rate"], epoch)
            if "misclassification_rate" in global_test_output["attack"]:
                wb.log({"misclassification_rate": global_test_output["attack"]["misclassification_rate"]})
                fedargs.tb.add_scalar("Misclassification Rate/", global_test_output["attack"]["misclassification_rate"], epoch)

        # Evaluate Backdoor
        if backdoor_attack["is"]:
            backdoor_test_output = fl.backdoor_test(global_model, backdoor_attack["loader"], device, backdoor_attack["target_label"])
            fedargs.tb.add_scalar("Backdoor Success Rate/", backdoor_test_output["accuracy"], epoch)
            wb.log({"backdoor_success_rate": backdoor_test_output["accuracy"]})
            log.jsoninfo(backdoor_test_output, "Backdoor Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))

        # CSV logging
        ltbl.ar({'epochs': epoch,'acc': global_test_output["accuracy"], 
                 'test_loss': global_test_output["test_loss"]})
        
        # Update client models
        for client in clients:
            client_details[client]['model'] = copy.deepcopy(global_model)

    # Clients
    tasks = [process(client, epoch, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()

    for client, update in zip(clients, updates):
        client_details[client]['model_update'] = update
    client_model_updates = {client: details["model_update"] for client, details in client_details.items()}
    
    # Fang attack
    if fang_attack["is"]:
        client_model_updates = fang_attack["func"](client_model_updates, len(mal_clients), fang_attack["kn"])
        
    # LIE attack
    if lie_attack["is"]:
        client_model_updates = lie_attack["func"](client_model_updates, len(mal_clients), lie_attack["kn"])
   
    # SOTA attack
    if sota_attack["is"]:
        client_model_updates = sota_attack["func"](client_model_updates, len(mal_clients), 
                                                   sota_attack["kn"], sota_attack["dev_type"])
    
    # FLtrust or FLTC based aggregation rules or attacks
    if FLTrust["is"]:
        global_model_update, _, _ = fedargs.train_func(global_model, FLTrust["loader"],
                                                       fedargs.learning_rate,
                                                       fedargs.weight_decay,
                                                       fedargs.local_rounds, device)

        # For Attacks related to FLTrust
        base_model_update = global_model_update
        if FLTrust["proxy"]["is"]:
            base_model_update, _, _ = fedargs.train_func(global_model, FLTrust["proxy"]["loader"],
                                                         fedargs.learning_rate,
                                                         fedargs.weight_decay,
                                                         fedargs.local_rounds, device)
        
        # Layer replacement attack
        if layer_replacement_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = layer_replacement_attack["func"](base_model_update,
                                                                                                   client_details[clients[client]]['model_update'],
                                                                                                   layer_replacement_attack["layers"])

        # For cosine attack, Malicious Clients
        if cosine_attack["is"]:
            p_models, params_changed = cosine_attack["func"](base_model_update, cosine_attack["args"], epoch,
                                                             client_model_updates, len(mal_clients), cosine_attack["kn"])
            
            for client, p_model in enumerate(p_models):
                client_details[clients[client]]['model_update'] = p_model 

            #plot params changed for only one client
            fedargs.tb.add_scalar("Params Changed for Cosine Attack/", params_changed, epoch)

        # For sybil attack, Malicious Clients
        if sybil_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = base_model_update
                
        # again pair, as changed during attack
        client_model_updates = {client: details["model_update"] for client, details in client_details.items()}

print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-12-30 12:11:36,051 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
#   2%|▏         | 1/51 [01:11<59:10, 71.01s/it]2021-12-30 12:12:46,766 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:12:50,344 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 1 of 51 {
#     "accuracy": 63.67,
#     "correct": 6367,
#     "test_loss": 2.2173554233551025
# } [MainProcess : MainThread (INFO)]
#   4%|▍         | 2/51 [02:26<1:00:18, 73.84s/it]2021-12-30 12:14:02,572 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:14:05,909 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 2 of 51 {
#     "accuracy": 73.94,
#     "correct": 7394,
#     "test_loss": 2.002077789306641
# } [MainProcess : MainThread (INFO)]
#   6%|▌         | 3/51 [03:37<57:46, 72.21s/it]  2021-12-30 12:15:12,848 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:15:16,709 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 3 of 51 {
#     "accuracy": 77.84,
#     "correct": 7784,
#     "test_loss": 1.7024699529647827
# } [MainProcess : MainThread (INFO)]
#   8%|▊         | 4/51 [04:52<57:36, 73.55s/it]2021-12-30 12:16:28,438 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:16:31,424 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 4 of 51 {
#     "accuracy": 80.22,
#     "correct": 8022,
#     "test_loss": 1.3728312940597533
# } [MainProcess : MainThread (INFO)]
#  10%|▉         | 5/51 [06:02<55:14, 72.06s/it]2021-12-30 12:17:37,864 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:17:42,952 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 5 of 51 {
#     "accuracy": 81.63,
#     "correct": 8163,
#     "test_loss": 1.0873442363739014
# } [MainProcess : MainThread (INFO)]
#  12%|█▏        | 6/51 [07:18<55:15, 73.69s/it]2021-12-30 12:18:54,713 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:18:57,316 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 6 of 51 {
#     "accuracy": 83.08,
#     "correct": 8308,
#     "test_loss": 0.8810237028121948
# } [MainProcess : MainThread (INFO)]
#  14%|█▎        | 7/51 [08:30<53:30, 72.98s/it]2021-12-30 12:20:06,212 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 7 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:20:08,700 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 7 of 51 {
#     "accuracy": 84.42,
#     "correct": 8442,
#     "test_loss": 0.7360712867736816
# } [MainProcess : MainThread (INFO)]
#  16%|█▌        | 8/51 [09:42<52:04, 72.66s/it]2021-12-30 12:21:18,202 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 8 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:21:21,248 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 8 of 51 {
#     "accuracy": 85.57000000000001,
#     "correct": 8557,
#     "test_loss": 0.636714691066742
# } [MainProcess : MainThread (INFO)]
#  18%|█▊        | 9/51 [10:51<50:06, 71.58s/it]2021-12-30 12:22:27,413 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 9 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:22:31,897 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 9 of 51 {
#     "accuracy": 86.65,
#     "correct": 8665,
#     "test_loss": 0.5645294543266296
# } [MainProcess : MainThread (INFO)]
#  20%|█▉        | 10/51 [12:08<50:05, 73.30s/it]2021-12-30 12:23:44,561 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 10 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:23:47,677 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 10 of 51 {
#     "accuracy": 87.17,
#     "correct": 8717,
#     "test_loss": 0.5161730135917664
# } [MainProcess : MainThread (INFO)]
#  22%|██▏       | 11/51 [13:25<49:32, 74.31s/it]2021-12-30 12:25:01,189 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 11 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:25:04,643 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 11 of 51 {
#     "accuracy": 87.75,
#     "correct": 8775,
#     "test_loss": 0.47822398648262027
# } [MainProcess : MainThread (INFO)]
#  24%|██▎       | 12/51 [14:35<47:27, 73.02s/it]2021-12-30 12:26:11,237 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 12 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:26:14,760 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 12 of 51 {
#     "accuracy": 88.16000000000001,
#     "correct": 8816,
#     "test_loss": 0.4493676106929779
# } [MainProcess : MainThread (INFO)]
#  25%|██▌       | 13/51 [15:50<46:39, 73.66s/it]2021-12-30 12:27:26,383 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 13 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:27:30,018 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 13 of 51 {
#     "accuracy": 88.77000000000001,
#     "correct": 8877,
#     "test_loss": 0.4270740877628326
# } [MainProcess : MainThread (INFO)]
#  27%|██▋       | 14/51 [17:04<45:30, 73.81s/it]2021-12-30 12:28:40,511 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 14 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:28:44,212 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 14 of 51 {
#     "accuracy": 88.87,
#     "correct": 8887,
#     "test_loss": 0.4085909888744354
# } [MainProcess : MainThread (INFO)]
#  29%|██▉       | 15/51 [18:20<44:41, 74.48s/it]2021-12-30 12:29:56,556 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 15 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:29:59,085 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 15 of 51 {
#     "accuracy": 89.27000000000001,
#     "correct": 8927,
#     "test_loss": 0.39383703942298887
# } [MainProcess : MainThread (INFO)]
#  31%|███▏      | 16/51 [19:32<43:00, 73.73s/it]2021-12-30 12:31:08,535 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 16 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:31:12,507 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 16 of 51 {
#     "accuracy": 89.60000000000001,
#     "correct": 8960,
#     "test_loss": 0.3802414209365845
# } [MainProcess : MainThread (INFO)]
#  33%|███▎      | 17/51 [20:47<41:54, 73.96s/it]2021-12-30 12:32:23,037 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 17 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:32:26,260 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 17 of 51 {
#     "accuracy": 89.98,
#     "correct": 8998,
#     "test_loss": 0.36916981592178344
# } [MainProcess : MainThread (INFO)]
#  35%|███▌      | 18/51 [22:01<40:44, 74.08s/it]2021-12-30 12:33:37,401 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 18 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:33:40,907 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 18 of 51 {
#     "accuracy": 89.92999999999999,
#     "correct": 8993,
#     "test_loss": 0.3602793737411499
# } [MainProcess : MainThread (INFO)]
#  37%|███▋      | 19/51 [23:16<39:35, 74.23s/it]2021-12-30 12:34:51,981 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 19 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:34:54,941 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 19 of 51 {
#     "accuracy": 90.3,
#     "correct": 9030,
#     "test_loss": 0.3504396085739136
# } [MainProcess : MainThread (INFO)]
#  39%|███▉      | 20/51 [24:30<38:19, 74.19s/it]2021-12-30 12:36:06,066 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 20 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:36:08,604 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 20 of 51 {
#     "accuracy": 90.58,
#     "correct": 9058,
#     "test_loss": 0.3434251808643341
# } [MainProcess : MainThread (INFO)]
#  41%|████      | 21/51 [25:42<36:44, 73.48s/it]2021-12-30 12:37:17,893 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 21 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:37:20,541 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 21 of 51 {
#     "accuracy": 90.8,
#     "correct": 9080,
#     "test_loss": 0.33548145747184754
# } [MainProcess : MainThread (INFO)]
#  43%|████▎     | 22/51 [26:52<35:07, 72.66s/it]2021-12-30 12:38:28,628 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 22 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:38:33,546 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 22 of 51 {
#     "accuracy": 90.93,
#     "correct": 9093,
#     "test_loss": 0.3291327766895294
# } [MainProcess : MainThread (INFO)]
#  45%|████▌     | 23/51 [28:05<33:51, 72.56s/it]2021-12-30 12:39:40,982 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 23 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:39:45,213 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 23 of 51 {
#     "accuracy": 91.11,
#     "correct": 9111,
#     "test_loss": 0.3230717500209808
# } [MainProcess : MainThread (INFO)]
#  47%|████▋     | 24/51 [29:20<33:02, 73.44s/it]2021-12-30 12:40:56,471 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 24 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:40:59,922 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 24 of 51 {
#     "accuracy": 91.21000000000001,
#     "correct": 9121,
#     "test_loss": 0.3176392308950424
# } [MainProcess : MainThread (INFO)]
#  49%|████▉     | 25/51 [30:34<31:54, 73.64s/it]2021-12-30 12:42:10,560 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 25 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:42:13,422 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 25 of 51 {
#     "accuracy": 91.3,
#     "correct": 9130,
#     "test_loss": 0.31217122015953064
# } [MainProcess : MainThread (INFO)]
#  51%|█████     | 26/51 [31:47<30:30, 73.22s/it]2021-12-30 12:43:22,816 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 26 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:43:27,037 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 26 of 51 {
#     "accuracy": 91.46,
#     "correct": 9146,
#     "test_loss": 0.3075984965801239
# } [MainProcess : MainThread (INFO)]
#  53%|█████▎    | 27/51 [33:01<29:23, 73.48s/it]2021-12-30 12:44:36,885 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 27 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:44:40,385 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 27 of 51 {
#     "accuracy": 91.55,
#     "correct": 9155,
#     "test_loss": 0.3028227160930634
# } [MainProcess : MainThread (INFO)]
#  55%|█████▍    | 28/51 [34:16<28:22, 74.04s/it]2021-12-30 12:45:52,226 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 28 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:45:54,908 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 28 of 51 {
#     "accuracy": 91.62,
#     "correct": 9162,
#     "test_loss": 0.2986076878547668
# } [MainProcess : MainThread (INFO)]
#  57%|█████▋    | 29/51 [35:29<26:59, 73.61s/it]2021-12-30 12:47:04,838 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 29 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:47:08,728 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 29 of 51 {
#     "accuracy": 91.75999999999999,
#     "correct": 9176,
#     "test_loss": 0.29480548028945924
# } [MainProcess : MainThread (INFO)]
#  59%|█████▉    | 30/51 [36:41<25:38, 73.27s/it]2021-12-30 12:48:17,300 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 30 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:48:21,146 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 30 of 51 {
#     "accuracy": 91.62,
#     "correct": 9162,
#     "test_loss": 0.290772700214386
# } [MainProcess : MainThread (INFO)]
#  61%|██████    | 31/51 [37:56<24:33, 73.69s/it]2021-12-30 12:49:31,970 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 31 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:49:35,894 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 31 of 51 {
#     "accuracy": 91.86,
#     "correct": 9186,
#     "test_loss": 0.28707991399765015
# } [MainProcess : MainThread (INFO)]
#  63%|██████▎   | 32/51 [39:11<23:28, 74.15s/it]2021-12-30 12:50:47,203 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 32 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:50:50,098 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 32 of 51 {
#     "accuracy": 91.82000000000001,
#     "correct": 9182,
#     "test_loss": 0.28382787456512454
# } [MainProcess : MainThread (INFO)]
#  65%|██████▍   | 33/51 [40:22<21:58, 73.25s/it]2021-12-30 12:51:58,369 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 33 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:52:02,881 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 33 of 51 {
#     "accuracy": 92.03,
#     "correct": 9203,
#     "test_loss": 0.2803325606822967
# } [MainProcess : MainThread (INFO)]
#  67%|██████▋   | 34/51 [41:38<21:00, 74.17s/it]2021-12-30 12:53:14,659 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 34 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:53:17,603 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 34 of 51 {
#     "accuracy": 92.08,
#     "correct": 9208,
#     "test_loss": 0.2772240797996521
# } [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [42:53<19:48, 74.26s/it]2021-12-30 12:54:29,130 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 35 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:54:33,084 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 35 of 51 {
#     "accuracy": 92.05,
#     "correct": 9205,
#     "test_loss": 0.2740262290239334
# } [MainProcess : MainThread (INFO)]
#  71%|███████   | 36/51 [44:06<18:30, 74.01s/it]2021-12-30 12:55:42,557 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 36 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:55:46,040 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 36 of 51 {
#     "accuracy": 92.12,
#     "correct": 9212,
#     "test_loss": 0.2713180649876595
# } [MainProcess : MainThread (INFO)]
#  73%|███████▎  | 37/51 [45:21<17:18, 74.21s/it]2021-12-30 12:56:57,240 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 37 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:57:01,086 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 37 of 51 {
#     "accuracy": 92.25999999999999,
#     "correct": 9226,
#     "test_loss": 0.268592486679554
# } [MainProcess : MainThread (INFO)]
#  75%|███████▍  | 38/51 [46:37<16:12, 74.82s/it]2021-12-30 12:58:13,482 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 38 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:58:16,168 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 38 of 51 {
#     "accuracy": 92.27,
#     "correct": 9227,
#     "test_loss": 0.26551378049850466
# } [MainProcess : MainThread (INFO)]
#  76%|███████▋  | 39/51 [47:51<14:53, 74.49s/it]2021-12-30 12:59:27,200 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 39 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:59:31,391 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 39 of 51 {
#     "accuracy": 92.30000000000001,
#     "correct": 9230,
#     "test_loss": 0.2629744628071785
# } [MainProcess : MainThread (INFO)]
#  78%|███████▊  | 40/51 [49:05<13:36, 74.26s/it]2021-12-30 13:00:40,944 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 40 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:00:44,935 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 40 of 51 {
#     "accuracy": 92.4,
#     "correct": 9240,
#     "test_loss": 0.26060816276073456
# } [MainProcess : MainThread (INFO)]
#  80%|████████  | 41/51 [50:17<12:17, 73.71s/it]2021-12-30 13:01:53,368 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 41 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:01:57,787 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 41 of 51 {
#     "accuracy": 92.43,
#     "correct": 9243,
#     "test_loss": 0.2574693945646286
# } [MainProcess : MainThread (INFO)]
#  82%|████████▏ | 42/51 [51:32<11:06, 74.05s/it]2021-12-30 13:03:08,195 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 42 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:03:12,858 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 42 of 51 {
#     "accuracy": 92.52,
#     "correct": 9252,
#     "test_loss": 0.2556544497013092
# } [MainProcess : MainThread (INFO)]
#  84%|████████▍ | 43/51 [52:44<09:48, 73.53s/it]2021-12-30 13:04:20,556 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 43 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:04:25,266 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 43 of 51 {
#     "accuracy": 92.58,
#     "correct": 9258,
#     "test_loss": 0.25313711495399477
# } [MainProcess : MainThread (INFO)]
#  86%|████████▋ | 44/51 [54:00<08:40, 74.31s/it]2021-12-30 13:05:36,658 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 44 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:05:39,720 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 44 of 51 {
#     "accuracy": 92.64,
#     "correct": 9264,
#     "test_loss": 0.2512072330713272
# } [MainProcess : MainThread (INFO)]
#  88%|████████▊ | 45/51 [55:16<07:27, 74.64s/it]2021-12-30 13:06:52,042 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 45 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:06:54,734 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 45 of 51 {
#     "accuracy": 92.78999999999999,
#     "correct": 9279,
#     "test_loss": 0.24897214957475663
# } [MainProcess : MainThread (INFO)]
#  90%|█████████ | 46/51 [56:32<06:15, 75.11s/it]2021-12-30 13:08:08,267 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 46 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:08:10,885 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 46 of 51 {
#     "accuracy": 92.80000000000001,
#     "correct": 9280,
#     "test_loss": 0.2465623355269432
# } [MainProcess : MainThread (INFO)]
#  92%|█████████▏| 47/51 [57:46<04:59, 74.87s/it]2021-12-30 13:09:22,580 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 47 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:09:25,079 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 47 of 51 {
#     "accuracy": 92.86999999999999,
#     "correct": 9287,
#     "test_loss": 0.2443741979598999
# } [MainProcess : MainThread (INFO)]
#  94%|█████████▍| 48/51 [59:02<03:45, 75.09s/it]2021-12-30 13:10:38,214 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 48 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:10:40,782 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 48 of 51 {
#     "accuracy": 92.97999999999999,
#     "correct": 9298,
#     "test_loss": 0.24219045144319534
# } [MainProcess : MainThread (INFO)]
#  96%|█████████▌| 49/51 [1:00:12<02:27, 73.60s/it]2021-12-30 13:11:48,320 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 49 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:11:52,190 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 49 of 51 {
#     "accuracy": 92.95,
#     "correct": 9295,
#     "test_loss": 0.24007355847358702
# } [MainProcess : MainThread (INFO)]
#  98%|█████████▊| 50/51 [1:01:26<01:13, 73.81s/it]2021-12-30 13:13:02,625 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 50 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:13:06,039 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 50 of 51 {
#     "accuracy": 93.10000000000001,
#     "correct": 9310,
#     "test_loss": 0.23797039657831193
# } [MainProcess : MainThread (INFO)]
# 100%|██████████| 51/51 [1:02:38<00:00, 73.70s/it]
# 3758.913341999054

# %% [markdown]
# <h1> End </h1>
