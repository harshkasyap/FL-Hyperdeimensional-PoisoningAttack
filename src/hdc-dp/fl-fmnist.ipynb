# %%
# %load_ext autoreload
# %autoreload 2

import asyncio, copy, os, socket, sys, time
from functools import partial
from multiprocessing import Pool, Process
from pathlib import Path
from tqdm import tqdm

import torch
from torch import optim
from torch.utils.tensorboard import SummaryWriter

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../../")))
from libs import agg, data, fl, hdc, helper, log, ltbl, nn, plot, poison, resnet, sim, wandb
from cfgs.fedargs import *

# %%
project = 'fl-hdc-dp'
name = 'fedavg-fmnist-na'

# Save Logs To File (info | debug | warning | error | critical) [optional]
log.init("info")
#log.init("info", name)
#log.init("debug", name)

#fedargs.agg_rule = agg.Rule.T_Mean
fedargs.dataset = "fmnist"
fedargs.tb = SummaryWriter('../../out/runs/' + project + '/' + name, comment="fl")
data_dict = {'epochs':[], 'acc': [], 'test_loss': []}
ltbl = ltbl.init(data_dict, name, project)
wb = wandb.init(name, project)
# Out:
# wandb: Currently logged in as: kasyah (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.9 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/kasyah/fl-hdc-dp/runs/2cro9u4u" target="_blank">fedavg-fmnist-na</a></strong> to <a href="https://wandb.ai/kasyah/fl-hdc-dp" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
# Device settings
use_cuda = fedargs.cuda and torch.cuda.is_available()
torch.manual_seed(fedargs.seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

# %%
# Prepare clients
host = socket.gethostname()
clients = [host + "(" + str(client + 1) + ")" for client in range(fedargs.num_clients)]

# %%
# Initialize Global and Client models
global_model = copy.deepcopy(fedargs.model)
# Load Data to clients
train_data, test_data = data.load_dataset(fedargs.dataset, only_to_tensor = True)

# %% [markdown]
# <h2>FLTrust</h2>

# %%
if FLTrust["is"]:
    train_data, FLTrust["data"] = data.random_split(train_data, FLTrust["ratio"])
    FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
    
    if FLTrust["proxy"]["is"]:
        FLTrust["data"], FLTrust["proxy"]["data"] = data.random_split(FLTrust["data"], FLTrust["proxy"]["ratio"])
        FLTrust["loader"] = torch.utils.data.DataLoader(FLTrust["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)
        FLTrust["proxy"]["loader"] = torch.utils.data.DataLoader(FLTrust["proxy"]["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Prepare a backdoored loader for test</h2>

# %%
if backdoor_attack["is"]:
    train_data, backdoor_attack["data"] = data.random_split(train_data, backdoor_attack["ratio"])
    backdoor_attack["data"] = poison.insert_trojan(backdoor_attack["data"],
                                                   backdoor_attack["target_label"],
                                                   backdoor_attack["trojan_func"], 1)
    backdoor_attack["loader"] = torch.utils.data.DataLoader(backdoor_attack["data"], batch_size=fedargs.client_batch_size, shuffle=True, **kwargs)

# %% [markdown]
# <h2>Load client's data</h2>

# %%
clients_data = data.split_data(train_data, clients)

# %% [markdown]
# <h2>HDC DP Attack</h2>

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def hdc_train(hdc_data, device, hdc_args):
    hdc_data_loader = torch.utils.data.DataLoader(hdc_data, batch_size=len(hdc_data), shuffle=True)
    hdc_model = hdc.HDC(hdc_args["one_d_len"], hdc_args["hdc_proj_len"], len(hdc_args["labels"]), device)
    train_acc = hdc_model.train(hdc_data_loader, device)
    return hdc_model

if hdc_dp_attack["is"]:
    hdc_tasks = [hdc_train(clients_data[clients[client]], device,
                            hdc_dp_attack["args"]) for client in mal_clients]
    try:
        hdc_models = fedargs.loop.run_until_complete(asyncio.gather(*hdc_tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling hdc_dps...")
        hdc_tasks.cancel()
        fedargs.loop.run_forever()
        hdc_tasks.exception()

    hdc_clients_data = {client: (clients_data[clients[client]], hdc_models[index])
                        for index, client in enumerate(mal_clients)}

    mal_clients_data = hdc_dp_attack["func"](hdc_clients_data,
                                             hdc_dp_attack["args"],
                                             label_flip_attack["labels"],
                                             hdc_dp_attack["percent"])

    for client, mal_data in enumerate(mal_clients_data):
        clients_data[clients[client]] = mal_data

# %% [markdown]
# <h2>Label Flip Attack</h2>

# %%
if label_flip_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = label_flip_attack["func"](clients_data[clients[client]],
                                                                  label_flip_attack["labels"],
                                                                  label_flip_attack["percent"])

# %% [markdown]
# <h2>Backdoor Attack</h2>

# %%
if backdoor_attack["is"]:
    for client in mal_clients:
        clients_data[clients[client]] = poison.insert_trojan(clients_data[clients[client]],
                                                             backdoor_attack["target_label"],
                                                             backdoor_attack["trojan_func"], 0.5)

# %%
client_train_loaders, _ = data.load_client_data(clients_data, fedargs.client_batch_size, None, **kwargs)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=fedargs.test_batch_size, shuffle=True, **kwargs)

client_details = {
        client: {"train_loader": client_train_loaders[client],
                 "model": copy.deepcopy(global_model),
                 "model_update": None}
        for client in clients
    }

# %%
def background(f):
    def wrapped(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, f, *args, **kwargs)

    return wrapped

@background
def process(client, epoch, model, train_loader, fedargs, device):
    # Train
    model_update, model, loss = fedargs.train_func(model, train_loader, 
                                                   fedargs.learning_rate,
                                                   fedargs.weight_decay,
                                                   fedargs.local_rounds, device)

    log.jsondebug(loss, "Epoch {} of {} : Federated Training loss, Client {}".format(epoch, fedargs.epochs, client))
    log.modeldebug(model_update, "Epoch {} of {} : Client {} Update".format(epoch, fedargs.epochs, client))
    
    return model_update

# %%
import time
start_time = time.time()
    
# Federated Training
for epoch in tqdm(range(fedargs.epochs)):
    log.info("Federated Training Epoch {} of {}".format(epoch, fedargs.epochs))

    # Global Model Update
    if epoch > 0:
        # For Tmean and FLTrust, not impacts others as of now
        avgargs = {"beta": len(mal_clients), 
                   "base_model_update": global_model_update if FLTrust["is"] else None,
                   "base_norm": True}
        
        # Average
        global_model = fl.federated_avg(client_model_updates, global_model, fedargs.agg_rule, **avgargs)
        log.modeldebug(global_model, "Epoch {}: Server Update".format(epoch))
        
        # Test, Plot and Log
        global_test_output = fedargs.eval_func(global_model, test_loader, device, label_flip_attack["labels"])
        fedargs.tb.add_scalar("Gloabl Accuracy/", global_test_output["accuracy"], epoch)
        fedargs.tb.add_scalar("Global Test Loss/", global_test_output["test_loss"], epoch)
        wb.log({"epoch": epoch, "time": time.time(), "acc": global_test_output["accuracy"], "loss": global_test_output["test_loss"]})
        log.jsoninfo(global_test_output, "Global Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))
        
        # Evaluate LFA
        if "attack" in global_test_output:
            if "attack_success_rate" in global_test_output["attack"]:
                wb.log({"attack_success_rate": global_test_output["attack"]["attack_success_rate"]})
                fedargs.tb.add_scalar("Attack Success Rate/", global_test_output["attack"]["attack_success_rate"], epoch)
            if "misclassification_rate" in global_test_output["attack"]:
                wb.log({"misclassification_rate": global_test_output["attack"]["misclassification_rate"]})
                fedargs.tb.add_scalar("Misclassification Rate/", global_test_output["attack"]["misclassification_rate"], epoch)

        # Evaluate Backdoor
        if backdoor_attack["is"]:
            backdoor_test_output = fl.backdoor_test(global_model, backdoor_attack["loader"], device, backdoor_attack["target_label"])
            fedargs.tb.add_scalar("Backdoor Success Rate/", backdoor_test_output["accuracy"], epoch)
            wb.log({"backdoor_success_rate": backdoor_test_output["accuracy"]})
            log.jsoninfo(backdoor_test_output, "Backdoor Test Outut after Epoch {} of {}".format(epoch, fedargs.epochs))

        # CSV logging
        ltbl.ar({'epochs': epoch,'acc': global_test_output["accuracy"], 
                 'test_loss': global_test_output["test_loss"]})
        
        # Update client models
        for client in clients:
            client_details[client]['model'] = copy.deepcopy(global_model)

    # Clients
    tasks = [process(client, epoch, client_details[client]['model'],
                     client_details[client]['train_loader'],
                     fedargs, device) for client in clients]
    try:
        updates = fedargs.loop.run_until_complete(asyncio.gather(*tasks))
    except KeyboardInterrupt as e:
        log.error("Caught keyboard interrupt. Canceling tasks...")
        tasks.cancel()
        fedargs.loop.run_forever()
        tasks.exception()

    for client, update in zip(clients, updates):
        client_details[client]['model_update'] = update
    client_model_updates = {client: details["model_update"] for client, details in client_details.items()}
    
    # Fang attack
    if fang_attack["is"]:
        client_model_updates = fang_attack["func"](client_model_updates, len(mal_clients), fang_attack["kn"])
        
    # LIE attack
    if lie_attack["is"]:
        client_model_updates = lie_attack["func"](client_model_updates, len(mal_clients), lie_attack["kn"])
   
    # SOTA attack
    if sota_attack["is"]:
        client_model_updates = sota_attack["func"](client_model_updates, len(mal_clients), 
                                                   sota_attack["kn"], sota_attack["dev_type"])
    
    # FLtrust or FLTC based aggregation rules or attacks
    if FLTrust["is"]:
        global_model_update, _, _ = fedargs.train_func(global_model, FLTrust["loader"],
                                                       fedargs.learning_rate,
                                                       fedargs.weight_decay,
                                                       fedargs.local_rounds, device)

        # For Attacks related to FLTrust
        base_model_update = global_model_update
        if FLTrust["proxy"]["is"]:
            base_model_update, _, _ = fedargs.train_func(global_model, FLTrust["proxy"]["loader"],
                                                         fedargs.learning_rate,
                                                         fedargs.weight_decay,
                                                         fedargs.local_rounds, device)
        
        # Layer replacement attack
        if layer_replacement_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = layer_replacement_attack["func"](base_model_update,
                                                                                                   client_details[clients[client]]['model_update'],
                                                                                                   layer_replacement_attack["layers"])

        # For cosine attack, Malicious Clients
        if cosine_attack["is"]:
            p_models, params_changed = cosine_attack["func"](base_model_update, cosine_attack["args"], epoch,
                                                             client_model_updates, len(mal_clients), cosine_attack["kn"])
            
            for client, p_model in enumerate(p_models):
                client_details[clients[client]]['model_update'] = p_model 

            #plot params changed for only one client
            fedargs.tb.add_scalar("Params Changed for Cosine Attack/", params_changed, epoch)

        # For sybil attack, Malicious Clients
        if sybil_attack["is"]:
            for client in mal_clients:
                client_details[clients[client]]['model_update'] = base_model_update
                
        # again pair, as changed during attack
        client_model_updates = {client: details["model_update"] for client, details in client_details.items()}

print(time.time() - start_time)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]2021-12-30 12:11:45,404 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 0 of 51 [MainProcess : MainThread (INFO)]
#   2%|▏         | 1/51 [01:09<57:33, 69.07s/it]2021-12-30 12:12:53,788 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 1 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:13:00,866 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 1 of 51 {
#     "accuracy": 52.64,
#     "correct": 5264,
#     "test_loss": 2.1874064079284667
# } [MainProcess : MainThread (INFO)]
#   4%|▍         | 2/51 [02:21<58:08, 71.19s/it]2021-12-30 12:14:06,471 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 2 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:14:13,918 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 2 of 51 {
#     "accuracy": 58.330000000000005,
#     "correct": 5833,
#     "test_loss": 1.8512587171554566
# } [MainProcess : MainThread (INFO)]
#   6%|▌         | 3/51 [03:37<58:35, 73.25s/it]2021-12-30 12:15:22,179 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 3 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:15:28,464 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 3 of 51 {
#     "accuracy": 60.81999999999999,
#     "correct": 6082,
#     "test_loss": 1.4874987854003907
# } [MainProcess : MainThread (INFO)]
#   8%|▊         | 4/51 [04:51<57:39, 73.61s/it]2021-12-30 12:16:36,349 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 4 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:16:43,231 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 4 of 51 {
#     "accuracy": 64.8,
#     "correct": 6480,
#     "test_loss": 1.213915129852295
# } [MainProcess : MainThread (INFO)]
#  10%|▉         | 5/51 [06:06<56:52, 74.19s/it]2021-12-30 12:17:51,555 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 5 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:17:57,022 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 5 of 51 {
#     "accuracy": 68.82000000000001,
#     "correct": 6882,
#     "test_loss": 1.0436533493995666
# } [MainProcess : MainThread (INFO)]
#  12%|█▏        | 6/51 [07:15<54:18, 72.40s/it]2021-12-30 12:19:00,482 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 6 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:19:06,303 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 6 of 51 {
#     "accuracy": 70.16,
#     "correct": 7016,
#     "test_loss": 0.9400531875610352
# } [MainProcess : MainThread (INFO)]
#  14%|█▎        | 7/51 [08:26<52:39, 71.81s/it]2021-12-30 12:20:11,062 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 7 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:20:18,194 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 7 of 51 {
#     "accuracy": 71.48,
#     "correct": 7148,
#     "test_loss": 0.8770859379768372
# } [MainProcess : MainThread (INFO)]
#  16%|█▌        | 8/51 [09:41<52:14, 72.89s/it]2021-12-30 12:21:26,282 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 8 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:21:32,711 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 8 of 51 {
#     "accuracy": 72.41,
#     "correct": 7241,
#     "test_loss": 0.831257237625122
# } [MainProcess : MainThread (INFO)]
#  18%|█▊        | 9/51 [10:56<51:28, 73.54s/it]2021-12-30 12:22:41,234 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 9 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:22:46,211 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 9 of 51 {
#     "accuracy": 72.99,
#     "correct": 7299,
#     "test_loss": 0.7971313131332397
# } [MainProcess : MainThread (INFO)]
#  20%|█▉        | 10/51 [12:09<50:01, 73.22s/it]2021-12-30 12:23:53,747 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 10 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:24:00,607 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 10 of 51 {
#     "accuracy": 73.49,
#     "correct": 7349,
#     "test_loss": 0.7691930274963379
# } [MainProcess : MainThread (INFO)]
#  22%|██▏       | 11/51 [13:24<49:15, 73.88s/it]2021-12-30 12:25:09,103 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 11 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:25:15,625 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 11 of 51 {
#     "accuracy": 73.83,
#     "correct": 7383,
#     "test_loss": 0.7478248797893524
# } [MainProcess : MainThread (INFO)]
#  24%|██▎       | 12/51 [14:36<47:35, 73.22s/it]2021-12-30 12:26:20,818 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 12 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:26:27,440 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 12 of 51 {
#     "accuracy": 74.03,
#     "correct": 7403,
#     "test_loss": 0.7295263488769531
# } [MainProcess : MainThread (INFO)]
#  25%|██▌       | 13/51 [15:50<46:36, 73.60s/it]2021-12-30 12:27:35,302 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 13 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:27:42,261 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 13 of 51 {
#     "accuracy": 74.25,
#     "correct": 7425,
#     "test_loss": 0.7137292469024659
# } [MainProcess : MainThread (INFO)]
#  27%|██▋       | 14/51 [17:05<45:36, 73.96s/it]2021-12-30 12:28:50,100 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 14 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:28:57,227 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 14 of 51 {
#     "accuracy": 74.39,
#     "correct": 7439,
#     "test_loss": 0.699889303445816
# } [MainProcess : MainThread (INFO)]
#  29%|██▉       | 15/51 [18:16<43:48, 73.01s/it]2021-12-30 12:30:00,906 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 15 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:30:08,706 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 15 of 51 {
#     "accuracy": 75.0,
#     "correct": 7500,
#     "test_loss": 0.686309736251831
# } [MainProcess : MainThread (INFO)]
#  31%|███▏      | 16/51 [19:34<43:27, 74.51s/it]2021-12-30 12:31:18,913 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 16 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:31:24,958 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 16 of 51 {
#     "accuracy": 75.22,
#     "correct": 7522,
#     "test_loss": 0.6759404797554016
# } [MainProcess : MainThread (INFO)]
#  33%|███▎      | 17/51 [20:47<42:03, 74.21s/it]2021-12-30 12:32:32,406 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 17 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:32:38,541 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 17 of 51 {
#     "accuracy": 75.48,
#     "correct": 7548,
#     "test_loss": 0.6651051320075989
# } [MainProcess : MainThread (INFO)]
#  35%|███▌      | 18/51 [22:01<40:43, 74.04s/it]2021-12-30 12:33:46,046 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 18 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:33:53,001 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 18 of 51 {
#     "accuracy": 75.86,
#     "correct": 7586,
#     "test_loss": 0.6552929353713989
# } [MainProcess : MainThread (INFO)]
#  37%|███▋      | 19/51 [23:15<39:29, 74.04s/it]2021-12-30 12:35:00,110 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 19 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:35:07,451 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 19 of 51 {
#     "accuracy": 76.33,
#     "correct": 7633,
#     "test_loss": 0.6468927571296692
# } [MainProcess : MainThread (INFO)]
#  39%|███▉      | 20/51 [24:27<37:58, 73.51s/it]2021-12-30 12:36:12,367 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 20 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:36:18,591 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 20 of 51 {
#     "accuracy": 76.4,
#     "correct": 7640,
#     "test_loss": 0.6386913680076599
# } [MainProcess : MainThread (INFO)]
#  41%|████      | 21/51 [25:39<36:31, 73.06s/it]2021-12-30 12:37:24,385 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 21 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:37:31,788 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 21 of 51 {
#     "accuracy": 76.78,
#     "correct": 7678,
#     "test_loss": 0.6317833397865296
# } [MainProcess : MainThread (INFO)]
#  43%|████▎     | 22/51 [26:56<35:52, 74.22s/it]2021-12-30 12:38:41,323 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 22 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:38:47,219 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 22 of 51 {
#     "accuracy": 77.06,
#     "correct": 7706,
#     "test_loss": 0.6248971039772033
# } [MainProcess : MainThread (INFO)]
#  45%|████▌     | 23/51 [28:06<34:04, 73.01s/it]2021-12-30 12:39:51,507 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 23 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:39:57,772 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 23 of 51 {
#     "accuracy": 77.24,
#     "correct": 7724,
#     "test_loss": 0.6176571831703186
# } [MainProcess : MainThread (INFO)]
#  47%|████▋     | 24/51 [29:20<32:58, 73.29s/it]2021-12-30 12:41:05,437 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 24 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:41:12,085 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 24 of 51 {
#     "accuracy": 77.42999999999999,
#     "correct": 7743,
#     "test_loss": 0.6122816373825073
# } [MainProcess : MainThread (INFO)]
#  49%|████▉     | 25/51 [30:34<31:46, 73.32s/it]2021-12-30 12:42:18,825 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 25 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:42:25,366 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 25 of 51 {
#     "accuracy": 77.60000000000001,
#     "correct": 7760,
#     "test_loss": 0.6064488367080688
# } [MainProcess : MainThread (INFO)]
#  51%|█████     | 26/51 [31:50<30:52, 74.09s/it]2021-12-30 12:43:34,745 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 26 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:43:40,454 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 26 of 51 {
#     "accuracy": 77.89,
#     "correct": 7789,
#     "test_loss": 0.6012526721000672
# } [MainProcess : MainThread (INFO)]
#  53%|█████▎    | 27/51 [33:02<29:26, 73.62s/it]2021-12-30 12:44:47,279 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 27 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:44:53,861 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 27 of 51 {
#     "accuracy": 78.03999999999999,
#     "correct": 7804,
#     "test_loss": 0.5965531673431397
# } [MainProcess : MainThread (INFO)]
#  55%|█████▍    | 28/51 [34:14<28:04, 73.24s/it]2021-12-30 12:45:59,600 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 28 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:46:07,268 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 28 of 51 {
#     "accuracy": 78.22,
#     "correct": 7822,
#     "test_loss": 0.5908771133422852
# } [MainProcess : MainThread (INFO)]
#  57%|█████▋    | 29/51 [35:30<27:10, 74.10s/it]2021-12-30 12:47:15,730 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 29 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:47:21,773 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 29 of 51 {
#     "accuracy": 78.29,
#     "correct": 7829,
#     "test_loss": 0.5869808259963989
# } [MainProcess : MainThread (INFO)]
#  59%|█████▉    | 30/51 [36:43<25:46, 73.64s/it]2021-12-30 12:48:28,274 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 30 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:48:34,663 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 30 of 51 {
#     "accuracy": 78.58000000000001,
#     "correct": 7858,
#     "test_loss": 0.5823853656768799
# } [MainProcess : MainThread (INFO)]
#  61%|██████    | 31/51 [37:57<24:37, 73.85s/it]2021-12-30 12:49:42,614 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 31 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:49:49,113 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 31 of 51 {
#     "accuracy": 78.71000000000001,
#     "correct": 7871,
#     "test_loss": 0.5785282981872558
# } [MainProcess : MainThread (INFO)]
#  63%|██████▎   | 32/51 [39:10<23:17, 73.58s/it]2021-12-30 12:50:55,571 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 32 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:51:02,896 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 32 of 51 {
#     "accuracy": 78.81,
#     "correct": 7881,
#     "test_loss": 0.574447898721695
# } [MainProcess : MainThread (INFO)]
#  65%|██████▍   | 33/51 [40:25<22:08, 73.78s/it]2021-12-30 12:52:09,822 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 33 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:52:15,862 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 33 of 51 {
#     "accuracy": 78.64999999999999,
#     "correct": 7865,
#     "test_loss": 0.5718353524208069
# } [MainProcess : MainThread (INFO)]
#  67%|██████▋   | 34/51 [41:38<20:51, 73.64s/it]2021-12-30 12:53:23,128 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 34 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:53:30,637 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 34 of 51 {
#     "accuracy": 78.99000000000001,
#     "correct": 7899,
#     "test_loss": 0.5671072239875794
# } [MainProcess : MainThread (INFO)]
#  69%|██████▊   | 35/51 [42:54<19:51, 74.48s/it]2021-12-30 12:54:39,563 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 35 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:54:46,097 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 35 of 51 {
#     "accuracy": 79.28,
#     "correct": 7928,
#     "test_loss": 0.563259863948822
# } [MainProcess : MainThread (INFO)]
#  71%|███████   | 36/51 [44:07<18:30, 74.05s/it]2021-12-30 12:55:52,611 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 36 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:55:58,818 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 36 of 51 {
#     "accuracy": 79.41,
#     "correct": 7941,
#     "test_loss": 0.5590045181274415
# } [MainProcess : MainThread (INFO)]
#  73%|███████▎  | 37/51 [45:22<17:19, 74.24s/it]2021-12-30 12:57:07,288 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 37 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:57:14,011 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 37 of 51 {
#     "accuracy": 79.43,
#     "correct": 7943,
#     "test_loss": 0.5564860019207001
# } [MainProcess : MainThread (INFO)]
#  75%|███████▍  | 38/51 [46:34<15:54, 73.40s/it]2021-12-30 12:58:18,725 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 38 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:58:26,500 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 38 of 51 {
#     "accuracy": 79.51,
#     "correct": 7951,
#     "test_loss": 0.5525956207275391
# } [MainProcess : MainThread (INFO)]
#  76%|███████▋  | 39/51 [47:53<15:03, 75.27s/it]2021-12-30 12:59:38,348 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 39 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 12:59:44,561 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 39 of 51 {
#     "accuracy": 79.59,
#     "correct": 7959,
#     "test_loss": 0.5501151802062988
# } [MainProcess : MainThread (INFO)]
#  78%|███████▊  | 40/51 [49:08<13:46, 75.18s/it]2021-12-30 13:00:53,324 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 40 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:00:58,675 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 40 of 51 {
#     "accuracy": 79.72,
#     "correct": 7972,
#     "test_loss": 0.5468082636833191
# } [MainProcess : MainThread (INFO)]
#  80%|████████  | 41/51 [50:22<12:27, 74.72s/it]2021-12-30 13:02:06,974 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 41 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:02:12,164 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 41 of 51 {
#     "accuracy": 79.94,
#     "correct": 7994,
#     "test_loss": 0.5439662742614746
# } [MainProcess : MainThread (INFO)]
#  82%|████████▏ | 42/51 [51:37<11:12, 74.77s/it]2021-12-30 13:03:21,868 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 42 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:03:26,686 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 42 of 51 {
#     "accuracy": 79.86,
#     "correct": 7986,
#     "test_loss": 0.5418373697757721
# } [MainProcess : MainThread (INFO)]
#  84%|████████▍ | 43/51 [52:47<09:48, 73.56s/it]2021-12-30 13:04:32,610 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 43 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:04:38,437 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 43 of 51 {
#     "accuracy": 79.99000000000001,
#     "correct": 7999,
#     "test_loss": 0.5386490957736969
# } [MainProcess : MainThread (INFO)]
#  86%|████████▋ | 44/51 [53:59<08:31, 73.06s/it]2021-12-30 13:05:44,477 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 44 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:05:52,055 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 44 of 51 {
#     "accuracy": 80.13,
#     "correct": 8013,
#     "test_loss": 0.5364858026027679
# } [MainProcess : MainThread (INFO)]
#  88%|████████▊ | 45/51 [55:12<07:17, 72.95s/it]2021-12-30 13:06:57,187 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 45 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:07:04,620 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 45 of 51 {
#     "accuracy": 80.36999999999999,
#     "correct": 8037,
#     "test_loss": 0.5330277369499207
# } [MainProcess : MainThread (INFO)]
#  90%|█████████ | 46/51 [56:26<06:05, 73.17s/it]2021-12-30 13:08:10,862 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 46 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:08:16,764 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 46 of 51 {
#     "accuracy": 80.51,
#     "correct": 8051,
#     "test_loss": 0.5306593561649322
# } [MainProcess : MainThread (INFO)]
#  92%|█████████▏| 47/51 [57:42<04:56, 74.20s/it]2021-12-30 13:09:27,484 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 47 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:09:34,461 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 47 of 51 {
#     "accuracy": 80.60000000000001,
#     "correct": 8060,
#     "test_loss": 0.5280877559661865
# } [MainProcess : MainThread (INFO)]
#  94%|█████████▍| 48/51 [58:57<03:43, 74.35s/it]2021-12-30 13:10:42,186 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 48 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:10:48,573 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 48 of 51 {
#     "accuracy": 80.62,
#     "correct": 8062,
#     "test_loss": 0.5259274768352509
# } [MainProcess : MainThread (INFO)]
#  96%|█████████▌| 49/51 [1:00:14<02:30, 75.17s/it]2021-12-30 13:11:59,258 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 49 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:12:05,647 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 49 of 51 {
#     "accuracy": 80.85,
#     "correct": 8085,
#     "test_loss": 0.5234935398578644
# } [MainProcess : MainThread (INFO)]
#  98%|█████████▊| 50/51 [1:01:27<01:14, 74.43s/it]2021-12-30 13:13:11,953 - <ipython-input-14-2815a2be5117>::<module>(l:6) : Federated Training Epoch 50 of 51 [MainProcess : MainThread (INFO)]
# 2021-12-30 13:13:18,754 - <ipython-input-14-2815a2be5117>::<module>(l:24) : Global Test Outut after Epoch 50 of 51 {
#     "accuracy": 80.89,
#     "correct": 8089,
#     "test_loss": 0.5217646452426911
# } [MainProcess : MainThread (INFO)]
# 100%|██████████| 51/51 [1:02:37<00:00, 73.69s/it]
# 3757.9567108154297

# %% [markdown]
# <h1> End </h1>
